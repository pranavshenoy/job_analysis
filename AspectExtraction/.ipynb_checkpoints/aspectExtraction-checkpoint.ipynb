# %%
import json
import os
import nltk
import numpy as np

# %%
all_reviews=[]
data=[]
for root, dirs, files in os.walk('Reviews/'):
    for name in dirs:                             #all review folders
        with open('Reviews/'+name+'/review.txt') as f:
            data=data+json.load(f)
            f.close()
dataset=[]
dataset=np.asarray(data)
dataset=np.concatenate(dataset)               #contains all the reviews

# %%
#tokenizing
tokens=[]
for review in dataset:
    tokens=tokens+nltk.word_tokenize(review)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9c7e30e1520a> in <module>()
#       2 tokens=[]
#       3 for review in dataset:
# ----> 4     tokens=tokens+nltk.word_tokenize(review)
#
# KeyboardInterrupt:

# %%
len(tokens)
# Out:
# 2388850

# %%
#pos tagging
tags=[]
tags=nltk.pos_tag(tokens)

# %%
len(tags)
# Out:
# 2388850

# %%
nouns=[]
for (a,b) in tags:
    if(b=='NN' or b=='NP' or b=='NNP'):
        nouns.append(a)
aspects=[]
[aspects.append((x,nouns.count(x))) for x in set(nouns)]
aspects=sorted(aspects,key=lambda x:x[1],reverse=True)

# %%
len(aspects)
# Out:
# 983

# %%
aspects
# Out:
# [(u'work', 24201),
#  (u'experience', 13896),
#  (u'job', 12596),
#  (u'Army', 11825),
#  (u'part', 10068),
#  (u'company', 9744),
#  (u'day', 9386),
#  (u'place', 9239),
#  (u'office', 8240),
#  (u'time', 7142),
#  (u'life', 6396),
#  (u'management', 6393),
#  (u'lot', 6037),
#  (u'team', 5567),
#  (u'culture', 5119),
#  (u'country', 4713),
#  (u'career', 4650),
#  (u'family', 4456),
#  (u'clerk', 3852),
#  (u'CLERK', 3852),
#  (u'duty', 3852),
#  (u'INDIAN', 3852),
#  (u'situation', 3852),
#  (u'ARMY', 3852),
#  (u'opportunity', 3525),
#  (u'member', 3256),
#  (u'balance', 3187),
#  (u'world', 3172),
#  (u'amp', 3039),
#  (u'environment', 2894),
#  (u'field', 2849),
#  (u'Great', 2757),
#  (u'EY', 2733),
#  (u'care', 2705),
#  (u'service', 2667),
#  (u'something', 2645),
#  (u'training', 2601),
#  (u'knowledge', 2465),
#  (u'everyone', 2315),
#  (u'organisation', 2151),
#  (u'development', 2119),
#  (u'period', 2038),
#  (u'US', 2035),
#  (u'improvement', 2029),
#  (u'Very', 2013),
#  (u'Corp', 2006),
#  (u'requirement', 2004),
#  (u'moment', 2001),
#  (u'workload', 1995),
#  (u'pool', 1995),
#  (u'equipment', 1984),
#  (u'Respect', 1981),
#  (u'manner', 1963),
#  (u'Lots', 1959),
#  (u'Deloitte', 1946),
#  (u'review', 1942),
#  (u'chair', 1926),
#  (u'co-operation', 1926),
#  (u'try', 1926),
#  (u'functioning', 1926),
#  (u'Korea', 1926),
#  (u'resume', 1926),
#  (u'militay', 1926),
#  (u'Focus', 1926),
#  (u'intellingence', 1926),
#  (u'chain', 1926),
#  (u'Ensure', 1926),
#  (u'motor', 1926),
#  (u'organaijestion', 1926),
#  (u'PERSONAL', 1926),
#  (u'science', 1926),
#  (u'coalition', 1926),
#  (u'challenging', 1926),
#  (u'U.S', 1926),
#  (u'HEAD', 1926),
#  (u'loyalty', 1926),
#  (u'adventure', 1926),
#  (u'Veteran', 1926),
#  (u'rank', 1926),
#  (u'regulation', 1926),
#  (u'Desert', 1926),
#  (u'WORKED', 1926),
#  (u'orderd', 1926),
#  (u'SUPERINDENT', 1926),
#  (u'Provide', 1926),
#  (u'frame', 1926),
#  (u'discipline', 1926),
#  (u'dedication', 1926),
#  (u'AND', 1926),
#  (u'OFFICE', 1926),
#  (u'Was', 1926),
#  (u'fro', 1926),
#  (u'privilege', 1926),
#  (u'Tele', 1926),
#  (u'IN', 1926),
#  (u'command', 1926),
#  (u'Alot', 1926),
#  (u'bearing', 1926),
#  (u'character', 1926),
#  (u'shortcut', 1926),
#  (u'wants/expect', 1926),
#  (u'emergency', 1926),
#  (u'success', 1926),
#  (u'institute/organisation', 1926),
#  (u'Operation', 1926),
#  (u'Storm', 1926),
#  (u'institution/organisation', 1926),
#  (u'head', 1926),
#  (u'interest', 1926),
#  (u'excitement', 1926),
#  (u'Punctuality', 1926),
#  (u'website', 1926),
#  (u'Electronics', 1926),
#  (u'ADVISOR', 1926),
#  (u'military', 1904),
#  (u'person', 1628),
#  (u'Management', 1605),
#  (u'organization', 1444),
#  (u'way', 1380),
#  (u'United', 1301),
#  (u'security', 1269),
#  (u'help', 1180),
#  (u'Work', 1174),
#  (u'chance', 1164),
#  (u'analyst', 1112),
#  (u'growth', 1061),
#  (u'learning', 1045),
#  (u'General', 1040),
#  (u'team-building', 1003),
#  (u'existence', 1003),
#  (u'Being', 1003),
#  (u'Germany', 1003),
#  (u'resource', 1003),
#  (u'intelligence', 1003),
#  (u'Finally', 1003),
#  (u'VII', 1003),
#  (u'profession', 1003),
#  (u'Adjutant', 1003),
#  (u'mature', 1003),
#  (u'age', 1003),
#  (u'HP', 974),
#  (u'room', 960),
#  (u'unit', 923),
#  (u'group', 915),
#  (u'employee', 910),
#  (u'level', 844),
#  (u'leadership', 828),
#  (u'process', 814),
#  (u'amount', 730),
#  (u'technology', 719),
#  (u'start', 704),
#  (u'need', 702),
#  (u'motivation', 682),
#  (u'maintenance', 675),
#  (u'communication', 667),
#  (u'i', 665),
#  (u'firm', 661),
#  (u'fun', 658),
#  (u'infantry', 654),
#  (u'course', 654),
#  (u'U.S.', 654),
#  (u'relief', 654),
#  (u'client', 645),
#  (u'exposure', 634),
#  (u'Annual', 633),
#  (u'%', 633),
#  (u'combat', 625),
#  (u'year', 615),
#  (u'position', 612),
#  (u'Training', 606),
#  (u'pressure', 600),
#  (u'sout', 596),
#  (u'chaos', 596),
#  (u'wisdom', 596),
#  (u'appreciation', 596),
#  (u'population', 596),
#  (u'mentality', 596),
#  (u'America', 596),
#  (u'computer', 596),
#  (u'core', 596),
#  (u'branch', 596),
#  (u'Company', 570),
#  (u'basis', 551),
#  (u'platform', 531),
#  (u'Good', 530),
#  (u'Oracle', 516),
#  (u'stress', 515),
#  (u'home', 507),
#  (u'anything', 503),
#  (u'end', 494),
#  (u'compensation', 493),
#  (u'analysis', 466),
#  (u'workplace', 464),
#  (u'MBA', 459),
#  (u'season', 457),
#  (u'information', 435),
#  (u'effort', 428),
#  (u'promotion', 426),
#  (u'Job', 422),
#  (u'industry', 422),
#  (u'aspect', 420),
#  (u'ability', 416),
#  (u'system', 406),
#  (u'scope', 395),
#  (u'market', 388),
#  (u'side', 385),
#  (u'reason', 383),
#  (u'Lot', 381),
#  (u'Senior', 369),
#  (u'brand', 365),
#  (u'Lead', 364),
#  (u'risk', 364),
#  (u'HR', 350),
#  (u'number', 343),
#  (u'Place', 341),
#  (u'disaster', 340),
#  (u'Ernst', 339),
#  (u'Young', 339),
#  (u'role', 336),
#  (u'audit', 335),
#  (u'graduate', 334),
#  (u'salary', 330),
#  (u'Ranger', 327),
#  (u'choice', 327),
#  (u'Graduate', 327),
#  (u'drag', 327),
#  (u'school', 327),
#  (u'Distinguished', 327),
#  (u'aid', 327),
#  (u'toxicity', 327),
#  (u'navigation', 327),
#  (u'assistance', 327),
#  (u'player', 327),
#  (u'mission', 327),
#  (u'machine', 327),
#  (u'Security', 327),
#  (u'language', 327),
#  (u'enforcement', 327),
#  (u'Food', 327),
#  (u'mother', 327),
#  (u'wire', 327),
#  (u'Piracy', 327),
#  (u'interdiction', 327),
#  (u'drawn', 327),
#  (u'Natural', 327),
#  (u'Honor', 327),
#  (u'drug', 327),
#  (u'Perform', 327),
#  (u'purpose', 327),
#  (u'left', 327),
#  (u'camouflage', 327),
#  (u'supervise', 327),
#  (u'Operate', 327),
#  (u'right', 327),
#  (u'Utilize', 327),
#  (u'Law', 327),
#  (u'ground', 327),
#  (u'land', 327),
#  (u'Service', 322),
#  (u'Manager', 315),
#  (u'Salary', 314),
#  (u'profile', 305),
#  (u'India', 301),
#  (u'respect', 301),
#  (u'skill', 301),
#  (u'Tax', 299),
#  (u'minute', 298),
#  (u'comraderie', 298),
#  (u'specialist', 298),
#  (u'NOT', 298),
#  (u'army', 298),
#  (u'Police', 298),
#  (u'Everyone', 298),
#  (u'police', 298),
#  (u'Iraq', 298),
#  (u'matter', 298),
#  (u'mine', 298),
#  (u'breakfast', 298),
#  (u'manipulation', 298),
#  (u'progress', 298),
#  (u'morning', 298),
#  (u'NCOs', 298),
#  (u'PM', 298),
#  (u'straight', 298),
#  (u'supply', 298),
#  (u'taser', 298),
#  (u'variety', 298),
#  (u'OC', 298),
#  (u'officer', 298),
#  (u'AM', 298),
#  (u'nothing', 297),
#  (u'pay', 292),
#  (u'Fun', 289),
#  (u'Employee', 289),
#  (u'consultant', 285),
#  (u'Associate', 277),
#  (u'business', 275),
#  (u'hike', 272),
#  (u'night', 269),
#  (u'bonus', 268),
#  (u'flow', 259),
#  (u'Nice', 258),
#  (u'trend', 255),
#  (u'manager', 254),
#  (u'Client', 254),
#  (u'offshore', 248),
#  (u'fresher', 244),
#  (u'problem', 234),
#  (u'preparation', 233),
#  (u'wise', 227),
#  (u'recruitment', 225),
#  (u'Content', 224),
#  (u'department', 224),
#  (u'Leadership', 222),
#  (u'performance', 220),
#  (u'Everything', 220),
#  (u'Less', 218),
#  (u'managing', 217),
#  (u'Claims', 215),
#  (u'Standard', 211),
#  (u'Industry', 211),
#  (u'evolving', 211),
#  (u'doubt', 211),
#  (u'Latest', 211),
#  (u'fit', 211),
#  (u'National', 211),
#  (u'approach', 211),
#  (u'you.They', 211),
#  (u'month', 209),
#  (u'working', 208),
#  (u'peer', 207),
#  (u'thing', 196),
#  (u'option', 192),
#  (u'shift', 192),
#  (u'A', 188),
#  (u'Business', 187),
#  (u'grow', 186),
#  (u'quality', 185),
#  (u'Culture', 184),
#  (u'project', 181),
#  (u'Team', 181),
#  (u'support', 181),
#  (u'talent', 178),
#  (u'Professional', 177),
#  (u'student', 177),
#  (u'focus', 171),
#  (u'atmosphere', 171),
#  (u'recognition', 170),
#  (u'learn', 168),
#  (u'Life', 167),
#  (u'reporting', 162),
#  (u'date', 161),
#  (u'satisfaction', 158),
#  (u'task', 155),
#  (u'flexibility', 154),
#  (u'Experience', 150),
#  (u'Advisory', 149),
#  (u'advisory', 149),
#  (u'Audit', 149),
#  (u'Corporate', 148),
#  (u'Laws', 148),
#  (u'structure', 147),
#  (u'Monthly', 146),
#  (u'consolidation', 146),
#  (u'challenge', 146),
#  (u'monitoring', 146),
#  (u'someone', 146),
#  (u'Auditing', 146),
#  (u'revenue', 146),
#  (u'Reports', 146),
#  (u'Chartered', 146),
#  (u'close', 146),
#  (u'Firms', 146),
#  (u'variance', 146),
#  (u'Plan', 146),
#  (u'rest', 146),
#  (u'thier', 146),
#  (u'vs.', 146),
#  (u'Financial', 142),
#  (u'policy', 142),
#  (u'man-management', 142),
#  (u'engineer', 142),
#  (u'Modelling', 142),
#  (u'Never', 140),
#  (u'candidate', 139),
#  (u'Knowledge', 133),
#  (u'No', 132),
#  (u'allowance', 130),
#  (u'money', 130),
#  (u'responsibility', 129),
#  (u'cross', 127),
#  (u'internship', 127),
#  (u'Growth', 127),
#  (u'WFH', 123),
#  (u'SAP', 123),
#  (u'product', 122),
#  (u'model', 120),
#  (u'benefit', 119),
#  (u'delivery', 119),
#  (u'practice', 117),
#  (u'customer', 116),
#  (u'Join', 115),
#  (u'GSG', 115),
#  (u'limit', 115),
#  (u'network', 114),
#  (u'Perfect', 113),
#  (u'clientele', 112),
#  (u'stage', 112),
#  (u'loving', 112),
#  (u'Perth', 112),
#  (u'mail', 112),
#  (u'return', 112),
#  (u'health', 112),
#  (u'People', 112),
#  (u'multibillion', 112),
#  (u'Fortune', 112),
#  (u'Risk', 112),
#  (u'enthusiasm', 112),
#  (u'Sydney', 112),
#  (u'Advanced', 112),
#  (u'Night', 112),
#  (u'Statutory', 112),
#  (u'World\u2019s', 112),
#  (u'Analyst', 112),
#  (u'Shift', 112),
#  (u'Melbourne', 112),
#  (u'energy', 111),
#  (u'Meetings', 111),
#  (u'Portfolio', 111),
#  (u'Planning', 111),
#  (u'door', 110),
#  (u'Organisation', 110),
#  (u'zero', 109),
#  (u'SQL.Good', 109),
#  (u'Informatica', 109),
#  (u'deloitte', 109),
#  (u'Enjoyed', 109),
#  (u'Working', 109),
#  (u'M', 109),
#  (u'college', 109),
#  (u'Workplace', 109),
#  (u'ETL', 109),
#  (u'Graduation', 109),
#  (u'accounting', 109),
#  (u'performing', 109),
#  (u'post', 109),
#  (u'networking', 109),
#  (u'path', 106),
#  (u'tax', 106),
#  (u'drawback', 106),
#  (u'individual', 103),
#  (u'approval', 103),
#  (u'freedom', 103),
#  (u'Fit', 102),
#  (u'respective', 102),
#  (u'attitude', 102),
#  (u'wellness', 102),
#  (u'College', 102),
#  (u'Balance', 102),
#  (u'peak', 102),
#  (u'Opportunity', 101),
#  (u'Ireland', 101),
#  (u'Price', 101),
#  (u'scale', 96),
#  (u'order', 95),
#  (u'percentage', 94),
#  (u'HPE', 93),
#  (u'example', 91),
#  (u'Learnt', 90),
#  (u'filing', 90),
#  (u'Time', 88),
#  (u'anyone', 88),
#  (u'feedback', 88),
#  (u'Handling', 88),
#  (u'Process', 87),
#  (u'Group', 87),
#  (u'line', 87),
#  (u'monitory', 84),
#  (u'assignment', 83),
#  (u'ORACLE', 82),
#  (u'result', 82),
#  (u'software', 80),
#  (u'ton', 77),
#  (u'building', 77),
#  (u'curve', 77),
#  (u'perseverance', 75),
#  (u'Adapt', 75),
#  (u'Org', 75),
#  (u'Too', 75),
#  (u'bangalore', 75),
#  (u'Servicing', 75),
#  (u'share', 75),
#  (u'presence', 75),
#  (u'Qualified', 75),
#  (u'Challenge', 75),
#  (u'Cool', 75),
#  (u'Leaving', 75),
#  (u'span', 75),
#  (u'hence', 75),
#  (u'seminar', 75),
#  (u'Development', 75),
#  (u'Vision', 75),
#  (u'Big', 75),
#  (u'Often', 75),
#  (u'seat', 75),
#  (u'commutation', 75),
#  (u'i.e', 75),
#  (u'commerce', 75),
#  (u'vision/mission', 75),
#  (u'survival', 75),
#  (u'Project', 75),
#  (u'traffic', 75),
#  (u'Highly', 75),
#  (u'table', 75),
#  (u'First', 75),
#  (u'Y.Got', 75),
#  (u'eg', 75),
#  (u'Transition', 75),
#  (u'E', 75),
#  (u'@', 74),
#  (u'race', 74),
#  (u'compliance', 74),
#  (u'Stamp', 74),
#  (u'use', 74),
#  (u'type', 74),
#  (u'Multi', 74),
#  (u'hardest', 74),
#  (u'currency', 74),
#  (u'tenure', 74),
#  (u'stability', 74),
#  (u'edge', 74),
#  (u'bank', 74),
#  (u'one', 74),
#  (u'portfolio', 74),
#  (u'Poor', 74),
#  (u'implementation', 74),
#  (u'full-time', 74),
#  (u'Everyday', 74),
#  (u'compromise', 74),
#  (u'CXO', 74),
#  (u'invoice', 74),
#  (u'o', 74),
#  (u'Duty', 74),
#  (u'Engineering', 74),
#  (u'oracle', 74),
#  (u'Compensation', 72),
#  (u'target', 72),
#  (u'solver', 71),
#  (u'advantage', 71),
#  (u'Linux', 71),
#  (u'Database', 71),
#  (u'VMware', 71),
#  (u'Mysql', 71),
#  (u'Cloud', 71),
#  (u'AWS', 71),
#  (u'hrs', 71),
#  (u'importance', 71),
#  (u'System', 71),
#  (u'Hp', 71),
#  (u'everybody', 70),
#  (u'till', 70),
#  (u'background', 70),
#  (u'data', 69),
#  (u'gen', 69),
#  (u'parent', 69),
#  (u'rope', 69),
#  (u'class', 69),
#  (u'CTC', 68),
#  (u'please', 68),
#  (u'Kaggle', 68),
#  (u'party', 68),
#  (u'lotz', 67),
#  (u'multiple', 65),
#  (u'client/project', 65),
#  (u'conduct', 65),
#  (u'My', 65),
#  (u'Pay.The', 65),
#  (u'transparency', 65),
#  (u'interview', 65),
#  (u'Huge', 65),
#  (u'base', 65),
#  (u'engagement', 65),
#  (u'recruiting', 65),
#  (u'incentive', 65),
#  (u'take', 65),
#  (u'notice', 65),
#  (u'stakeholder', 65),
#  (u'match', 65),
#  (u'bit', 65),
#  (u'seating', 65),
#  (u'transport', 65),
#  (u'PTO', 65),
#  (u'repository', 65),
#  (u'Awesome', 65),
#  (u'floor', 65),
#  (u'Competitive', 65),
#  (u'Goal', 64),
#  (u'advancement', 64),
#  (u'Excellent', 64),
#  (u'Merge', 64),
#  (u'Hike', 62),
#  (u'lack', 59),
#  (u'Managers', 59),
#  (u'size', 59),
#  (u'roles', 59),
#  (u'entry', 59),
#  (u'par', 59),
#  (u'Jobs', 59),
#  (u'consulting', 59),
#  (u'Basically', 58),
#  (u'decision', 56),
#  (u'Pride', 55),
#  (u'Value', 55),
#  (u'CSC', 55),
#  (u'merger', 55),
#  (u'Company.The', 55),
#  (u'Abundance', 55),
#  (u'Multinational', 55),
#  (u'delay', 55),
#  (u'Productive', 55),
#  (u'Occasional', 55),
#  (u'name', 55),
#  (u'bay', 55),
#  (u'supper', 55),
#  (u'accordance', 55),
#  (u'venture', 55),
#  (u'Brand', 55),
#  (u'fail', 55),
#  (u'region', 55),
#  (u'Understanding', 55),
#  (u'Validate', 55),
#  (u'Hewlett-Packard', 55),
#  (u'deviation', 55),
#  (u'lead', 55),
#  (u'Policies', 55),
#  (u'image', 55),
#  (u'idea', 55),
#  (u'Charity', 55),
#  (u'Advance', 55),
#  (u'rate', 53),
#  (u'personality', 53),
#  (u'nature', 50),
#  (u'Learning', 49),
#  (u'developer', 48),
#  (u'overall.Clean', 48),
#  (u'designation', 48),
#  (u'Flexibilty', 48),
#  (u'circle', 48),
#  (u'contribution', 48),
#  (u'application', 48),
#  (u'everything', 48),
#  (u'Hewlett', 45),
#  (u'facility', 45),
#  (u'Packard', 45),
#  (u'Analytics', 45),
#  (u'thought', 45),
#  (u'Environment', 43),
#  (u'.Net', 40),
#  (u'setup', 40),
#  (u'SharePoint', 40),
#  (u'infrastructure', 40),
#  (u'compare', 40),
#  (u'Digital', 40),
#  (u'Bonus', 40),
#  (u'discussion', 40),
#  (u'Practice', 40),
#  (u'coding', 40),
#  (u'Guidewire', 40),
#  (u'nobody', 40),
#  (u'future', 40),
#  (u'face', 40),
#  (u'Retention', 40),
#  (u'employer', 40),
#  (u'leisure', 40),
#  (u'Oregon', 40),
#  (u'mark', 40),
#  (u'Cybersecurity', 40),
#  (u'Allianz', 40),
#  (u'IT', 40),
#  (u'anybody', 40),
#  (u'con', 40),
#  (u'Java', 40),
#  (u'Nothing', 40),
#  (u'package', 40),
#  (u'carrier', 40),
#  (u'India.Salary', 40),
#  (u'forward', 40),
#  (u'Awards', 40),
#  (u'Promising', 40),
#  (u'acceptance', 40),
#  (u'etc.and', 40),
#  (u'Reporting', 37),
#  (u'-I', 37),
#  (u'Chennai', 37),
#  (u'Deloitte\u201d', 37),
#  (u'EOD', 37),
#  (u'pride', 37),
#  (u'collaborate', 37),
#  (u'progression', 37),
#  (u'client\u2019s', 37),
#  (u'mentor', 37),
#  (u'regardless', 37),
#  (u'Operational', 37),
#  (u'Notices', 37),
#  (u'motivate', 37),
#  (u'call', 37),
#  (u'Onsite', 37),
#  (u'Services', 37),
#  (u'carrom', 37),
#  (u'everyday', 37),
#  (u'Certified', 37),
#  (u'documentation', 37),
#  (u'Flexibility', 37),
#  (u'rapport', 37),
#  (u'Body', 37),
#  (u'Tolani', 37),
#  (u'generation', 37),
#  (u'globe', 37),
#  (u'Deepak', 37),
#  (u'Junior', 37),
#  (u'Transaction', 37),
#  (u'associate', 37),
#  (u'card', 37),
#  (u'interaction', 37),
#  (u'offsite', 37),
#  (u'Amex', 37),
#  (u'Incorporation', 37),
#  (u'Fraud', 37),
#  (u'Companies', 37),
#  (u'kind', 37),
#  (u'Bad/Arrogant', 37),
#  (u'Pay', 37),
#  (u'Designing', 37),
#  (u'contact', 37),
#  (u'Bank', 37),
#  (u'accuracy', 37),
#  (u'payment', 37),
#  (u'Memos', 37),
#  (u'Foosball', 37),
#  (u'Particulars', 37),
#  (u'relation', 37),
#  (u'Nevertheless', 37),
#  (u'Minutes', 37),
#  (u'banking', 37),
#  (u'stuff', 37),
#  (u'activity', 37),
#  (u'set', 37),
#  (u'attention', 37),
#  (u'Directors', 37),
#  (u'point', 37),
#  (u'pot', 37),
#  (u'walk', 37),
#  (u'Board', 37),
#  (u'Advises', 37),
#  (u'Processing', 37),
#  (u'teamwork', 37),
#  (u'meeting', 37),
#  (u'Card', 37),
#  (u'Face', 37),
#  (u'Credit', 37),
#  (u'cluster', 37),
#  (u'composition', 37),
#  (u'director', 37),
#  (u'consistency', 37),
#  (u'Quality', 37),
#  (u'summer', 37),
#  (u'accurate', 37),
#  (u'coordination', 37),
#  (u'Friday', 37),
#  (u'bench', 37),
#  (u'government', 37),
#  (u'creation', 37),
#  (u'Listed', 37),
#  (u'Vendor', 37),
#  (u'ROC', 37),
#  (u'step', 37),
#  (u'dependence', 37),
#  (u'range', 37),
#  (u'Committee', 37),
#  (u'Customized', 37),
#  (u'valuation', 37),
#  (u'duration', 37),
#  (u'lawns', 37),
#  (u'corporation', 37),
#  (u'excel', 37),
#  (u'detail', 37),
#  (u'Examiner', 37),
#  (u'Technical', 36),
#  (u'domain', 35),
#  (u'Career', 34),
#  (u'space', 34),
#  (u'holiday', 33),
#  (u'hyderabad', 33),
#  (u'Helpful', 33),
#  (u'Off', 33),
#  (u'proud', 33),
#  (u'Saturday', 33),
#  (u'fear', 33),
#  (u'laptop', 33),
#  (u'retaliation', 33),
#  (u'Friendly', 33),
#  (u'maternity', 33),
#  (u'competition', 33),
#  (u'schedule', 33),
#  (u'block', 33),
#  (u'log', 33),
#  (u'guiding', 32),
#  (u'exchange', 32),
#  (u'standard', 32),
#  (u'guidance', 32),
#  (u'Work-life', 32),
#  (u'SBC', 32),
#  (u'status', 32),
#  (u'Spain', 32),
#  (u'food', 32),
#  (u'Magament', 32),
#  (u'Ensured', 32),
#  (u'Transparent', 32),
#  (u'self', 32),
#  (u'Bangalore', 32),
#  (u'efficiency', 32),
#  (u'warmth', 32),
#  (u'Co', 32),
#  (u'board', 32),
#  (u'execution', 32),
#  (u'page', 32),
#  (u'professional', 32),
#  (u'CEO', 32),
#  (u'End', 31),
#  (u'Compensation/Benefits', 29),
#  (u'cost', 29),
#  (u'Balanced', 29),
#  (u'cab', 29),
#  (u'closing', 29),
#  (u'appraisal', 29),
#  (u'salary.I', 29),
#  (u'Cab', 29),
#  (u'wont', 29),
#  (u'hp', 29),
#  (u'joining', 29),
#  (u'vision', 29),
#  (u'concern', 29),
#  (u'Security/Advancement', 29),
#  (u'value', 29),
#  (u'best..', 29),
#  (u'opp', 29),
#  (u'run', 29),
#  (u'great.One', 29),
#  (u'ESS', 26),
#  (u'Better', 26),
#  (u'specs', 26),
#  (u'Infrastructure', 26),
#  (u'Work/Life', 26),
#  (u'partner', 26),
#  (u'workforce', 26),
#  (u'Lacks', 22),
#  (u'assurance', 22),
#  (u'Information', 22),
#  (u'Be', 22),
#  (u'Domain', 22),
#  (u'Insurance', 22),
#  (u'Variety', 22),
#  (u'Intern', 22),
#  (u'week', 22),
#  (u'Non', 18),
#  (u'travel', 18),
#  (u'Big4', 18),
#  (u'Breaks', 18),
#  (u'harder', 18),
#  (u'Offers', 18),
#  (u'Challenging', 16),
#  (u'Digital/', 16),
#  (u'dial', 16),
#  (u'potential', 16),
#  (u'engine', 16),
#  (u'secure', 16),
#  (u'sister', 16),
#  (u'making', 16),
#  (u'hold', 16),
#  (u'escalate', 16),
#  (u'enterprise', 16),
#  (u'faulty', 16),
#  (u'issues.following', 16),
#  (u'Always', 16),
#  (u'Encourages', 16),
#  (u'trainee', 16),
#  (u'Inc', 16),
#  (u'foward', 16),
#  (u'Unlimited', 16),
#  (u'Exposure', 16),
#  (u'Due', 16),
#  (u'house', 16),
#  (u'company.It', 16),
#  (u'merchandising', 16),
#  (u'Extension', 16),
#  (u'feel', 16),
#  (u'priority', 16),
#  (u'sheet', 16),
#  (u'enhancement', 16),
#  (u'evaluation', 16),
#  (u'restriction', 16),
#  (u'Recreational', 16),
#  (u'managent', 16),
#  (u'IP/', 16),
#  (u'adaptability', 16),
#  (u'staff', 16),
#  (u'opening', 16),
#  (u'Leader', 16),
#  (u'spirit', 16),
#  (u'contract', 16),
#  (u'productivity', 16),
#  (u'split', 16),
#  (u'Order', 16),
#  (u'DHCP', 16),
#  (u'Technology', 16),
#  (u'well', 16),
#  (u'mingle', 16),
#  (u'Faulty', 16),
#  (u'accordingly.Communication', 16),
#  (u'boon', 16),
#  (u'game', 16),
#  (u'married.Hence', 16),
#  (u'communication.Management', 16),
#  (u'greeting', 16),
#  (u'specter', 16),
#  (u'Hyderabad', 16),
#  (u'area', 16),
#  (u'*', 16),
#  (u'ADP', 16),
#  (u'Hardest', 16),
#  (u'Avaya', 16),
#  (u'OTC', 16),
#  (u'Srdash', 16),
#  (u'Hardware', 16),
#  (u'tone', 16),
#  (u'Profiling', 16),
#  (u'Analog', 16),
#  (u'TAT', 13),
#  (u'External', 13),
#  (u'Enterprise', 13),
#  (u'joiner', 13),
#  (u'EDI', 13),
#  (u'regression', 13),
#  (u'invoicing', 13),
#  (u'Settling', 13),
#  (u'Test', 13),
#  (u'port', 13),
#  (u'we19', 13),
#  (u'recovery', 13),
#  (u'term', 13),
#  (u'issue', 13),
#  (u'definition', 13),
#  (u'User', 13),
#  (u'Adoption', 13),
#  (u'increment', 13),
#  (u'plan', 13),
#  (u'track', 13),
#  (u'SAP-third', 13),
#  (u'etc', 13),
#  (u'Monitoring', 13),
#  (u'production', 13),
#  (u'inbound', 13),
#  (u'Action', 13),
#  (u'Logistics', 13),
#  (u'automation', 13),
#  (u'bd87', 13),
#  (u'Release', 13),
#  (u'/', 13),
#  (u't', 13),
#  (u'transfer', 13),
#  (u'Allotted', 13),
#  (u'we02', 13),
#  (u'CDP', 13),
#  (u'Delivery', 13),
#  (u'Acceptance', 13),
#  (u'Site', 13),
#  (u'PSG', 13),
#  (u'Attended', 10),
#  (u'HCL', 10),
#  (u'healthcare', 10),
#  (u'Cleared', 10),
#  (u'Apps', 10),
#  (u'GYM', 10)]

# %%
with  open('aspect.txt','w') as f:
    json.dump(aspects,f)
