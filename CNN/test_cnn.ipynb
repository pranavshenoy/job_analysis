# %%
import tensorflow as tf

# %%
with tf.device('/cpu:0'), tf.name_scope('embeddings'):
    W=tf.Variable(tf.random_uniform([10,20],-1000,1000),name="W")
print W

# %%
sess=tf.Session()
init=tf.initialize_all_variables()
sess.run(init)
sess.run(W)
# Out:
# array([[ 872.73144531, -195.01068115,  999.48449707, -977.51330566,
#         -741.890625  , -177.25994873,  603.30175781,  466.81933594,
#         -364.82403564,  177.77441406,  701.89685059,  913.75878906,
#          245.84265137,  126.10986328, -942.17822266,  -57.79602051,
#         -581.2130127 , -774.15301514, -876.99224854, -289.96588135],
#        [ -82.83996582, -863.59545898, -697.15570068, -379.63342285,
#          624.34960938,  339.56982422, -688.22570801,  327.92993164,
#          357.07043457,  358.46777344,  861.57727051,  452.20849609,
#         -482.16625977,  -69.2401123 , -650.95397949,  707.37268066,
#          569.90246582,  794.95458984, -964.37286377,  116.26696777],
#        [-452.91137695, -380.19488525,  219.19555664,  -91.76062012,
#           67.11364746,  522.99926758, -989.58374023,  542.34143066,
#          584.3996582 ,  358.48120117, -275.36962891, -946.53869629,
#          605.19165039, -250.83734131,   52.28137207,  154.42993164,
# ...
