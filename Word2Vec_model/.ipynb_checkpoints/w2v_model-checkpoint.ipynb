# %%
import json
import gensim
from nltk.corpus import stopwords
import nltk
import re
import numpy as np
from nltk.stem import PorterStemmer
import os
import enchant
from nltk.tokenize import RegexpTokenizer

# %%
#fetch all reviews
data=[]
for root, dirs, files in os.walk('../Reviews/'):
    for name in dirs:                             #all review folders
        with open('../Reviews/'+name+'/review.txt') as f:
            data=data+json.load(f)
            f.close()
dataset=[]
dataset=np.asarray(data)
dataset=np.concatenate(dataset)               #contains all the reviews

# %%
#initialising dictionary, tokenizer, stemmer
dictionary = enchant.Dict("en_US")
tokenizer=RegexpTokenizer('[a-zA-Z]+')
ps=PorterStemmer()
all_stopwords=stopwords.words('english')+['ibm','amazon']

# %%
def preprocess(sentence):
    dataset=[]
    print 'sentence : '+sentence
    temp=tokenizer.tokenize(sentence)
    print 'tokenizer : '+str(temp)
    only_english=[word for word in temp if dictionary.check(word)== True]  # remove non-english words
    print 'removed all non-english words : '+str(only_english)
    return  only_english           # returns tokens

# %%
def tokenize_review(review):                # for tokenizing single reviews
    review=review.lower()
    review_tokens=[]
    review=review.replace('.',',')        
    print 'Review : '+review
    sentences=re.split(' and | but |, ',review) 
    for sentence in sentences:
        print ' '
        temp=preprocess(sentence)
        if(len(temp)>1):
            review_tokens.append(temp)
    return review_tokens

# %%
#only for displaying
tokenize_review(dataset[77])
# Out:
# Review :  yes,it's a good company to work on and learn new things in your track,lot of opportunities provided by the company to learn cross module experience, it also has a good work life balance
#
# sentence :  yes,it's a good company to work on
# tokenizer : [u'yes', u'it', u's', u'a', u'good', u'company', u'to', u'work', u'on']
# removed all non-english words : [u'yes', u'it', u's', u'a', u'good', u'company', u'to', u'work', u'on']
#
# sentence : learn new things in your track,lot of opportunities provided by the company to learn cross module experience
# tokenizer : [u'learn', u'new', u'things', u'in', u'your', u'track', u'lot', u'of', u'opportunities', u'provided', u'by', u'the', u'company', u'to', u'learn', u'cross', u'module', u'experience']
# removed all non-english words : [u'learn', u'new', u'things', u'in', u'your', u'track', u'lot', u'of', u'opportunities', u'provided', u'by', u'the', u'company', u'to', u'learn', u'cross', u'module', u'experience']
#
# sentence : it also has a good work life balance
# tokenizer : [u'it', u'also', u'has', u'a', u'good', u'work', u'life', u'balance']
# removed all non-english words : [u'it', u'also', u'has', u'a', u'good', u'work', u'life', u'balance']
# [[u'yes', u'it', u's', u'a', u'good', u'company', u'to', u'work', u'on'],
#  [u'learn',
#   u'new',
#   u'things',
#   u'in',
#   u'your',
#   u'track',
#   u'lot',
#   u'of',
#   u'opportunities',
#   u'provided',
#   u'by',
#   u'the',
#   u'company',
#   u'to',
#   u'learn',
#   u'cross',
#   u'module',
#   u'experience'],
#  [u'it', u'also', u'has', u'a', u'good', u'work', u'life', u'balance']]

# %%
def tokenize_all(dataset):               # for tokenizing all the reviews
    tokens=[]
    for review in dataset:
        tokens=tokens+tokenize_review(review)
    return tokens

# %%
#'tokens' contain all the tokens
tokens=tokenize_all(dataset)
# Out:
# Review :  ibm provides immense opportunities to its employees in terms of career opportunities, with its global presence ibm is an international brand which has the potential to attract talents all across the globe
#
# sentence :  ibm provides immense opportunities to its employees in terms of career opportunities
# tokenizer : [u'ibm', u'provides', u'immense', u'opportunities', u'to', u'its', u'employees', u'in', u'terms', u'of', u'career', u'opportunities']
# removed all non-english words : [u'provides', u'immense', u'opportunities', u'to', u'its', u'employees', u'in', u'terms', u'of', u'career', u'opportunities']
#
# sentence : with its global presence ibm is an international brand which has the potential to attract talents all across the globe
# tokenizer : [u'with', u'its', u'global', u'presence', u'ibm', u'is', u'an', u'international', u'brand', u'which', u'has', u'the', u'potential', u'to', u'attract', u'talents', u'all', u'across', u'the', u'globe']
# removed all non-english words : [u'with', u'its', u'global', u'presence', u'is', u'an', u'international', u'brand', u'which', u'has', u'the', u'potential', u'to', u'attract', u'talents', u'all', u'across', u'the', u'globe']
# Review :  good work life balance salary not on the mark as per the qualification and experience overcrowded team due to which not so much to proof one's performance and quality
#
# sentence :  good work life balance salary not on the mark as per the qualification
# tokenizer : [u'good', u'work', u'life', u'balance', u'salary', u'not', u'on', u'the', u'mark', u'as', u'per', u'the', u'qualification']
# removed all non-english words : [u'good', u'work', u'life', u'balance', u'salary', u'not', u'on', u'the', u'mark', u'as', u'per', u'the', u'qualification']
#
# sentence : experience overcrowded team due to which not so much to proof one's performance
# tokenizer : [u'experience', u'overcrowded', u'team', u'due', u'to', u'which', u'not', u'so', u'much', u'to', u'proof', u'one', u's', u'performance']
# removed all non-english words : [u'experience', u'overcrowded', u'team', u'due', u'to', u'which', u'not', u'so', u'much', u'to', u'proof', u'one', u's', u'performance']
#
# sentence : quality
# tokenizer : [u'quality']
# removed all non-english words : [u'quality']
# Review :  i worked at ibm as an intern  pros  convenient location vibrant company culture in house gym, library, entertainment  cons  work life balance can be an issue limited exposer to the product and process
#
# sentence :  i worked at ibm as an intern  pros  convenient location vibrant company culture in house gym
# tokenizer : [u'i', u'worked', u'at', u'ibm', u'as', u'an', u'intern', u'pros', u'convenient', u'location', u'vibrant', u'company', u'culture', u'in', u'house', u'gym']
# removed all non-english words : [u'i', u'worked', u'at', u'as', u'an', u'intern', u'pros', u'convenient', u'location', u'vibrant', u'company', u'culture', u'in', u'house', u'gym']
#
# sentence : library
# tokenizer : [u'library']
# removed all non-english words : [u'library']
#
# sentence : entertainment  cons  work life balance can be an issue limited exposer to the product
# tokenizer : [u'entertainment', u'cons', u'work', u'life', u'balance', u'can', u'be', u'an', u'issue', u'limited', u'exposer', u'to', u'the', u'product']
# removed all non-english words : [u'entertainment', u'cons', u'work', u'life', u'balance', u'can', u'be', u'an', u'issue', u'limited', u'exposer', u'to', u'the', u'product']
#
# sentence : process
# tokenizer : [u'process']
# removed all non-english words : [u'process']
# Review :  amazing place to work at, takes care of work life balance and provides flexibility to maximize the performance of employee, proud to be associated with the organization,
#
# sentence :  amazing place to work at
# tokenizer : [u'amazing', u'place', u'to', u'work', u'at']
# removed all non-english words : [u'amazing', u'place', u'to', u'work', u'at']
#
# sentence : takes care of work life balance
# tokenizer : [u'takes', u'care', u'of', u'work', u'life', u'balance']
# removed all non-english words : [u'takes', u'care', u'of', u'work', u'life', u'balance']
#
# sentence : provides flexibility to maximize the performance of employee
# tokenizer : [u'provides', u'flexibility', u'to', u'maximize', u'the', u'performance', u'of', u'employee']
# removed all non-english words : [u'provides', u'flexibility', u'to', u'maximize', u'the', u'performance', u'of', u'employee']
#
# sentence : proud to be associated with the organization
# tokenizer : [u'proud', u'to', u'be', u'associated', u'with', u'the', u'organization']
# removed all non-english words : [u'proud', u'to', u'be', u'associated', u'with', u'the', u'organization']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  good company flexible working hours friendly working culture with in teams and overall comapny too helpful to gain knowledge with the trainings provided internally women employee frienldy
#
# sentence :  good company flexible working hours friendly working culture with in teams
# tokenizer : [u'good', u'company', u'flexible', u'working', u'hours', u'friendly', u'working', u'culture', u'with', u'in', u'teams']
# removed all non-english words : [u'good', u'company', u'flexible', u'working', u'hours', u'friendly', u'working', u'culture', u'with', u'in', u'teams']
#
# sentence : overall comapny too helpful to gain knowledge with the trainings provided internally women employee frienldy
# tokenizer : [u'overall', u'comapny', u'too', u'helpful', u'to', u'gain', u'knowledge', u'with', u'the', u'trainings', u'provided', u'internally', u'women', u'employee', u'frienldy']
# removed all non-english words : [u'overall', u'too', u'helpful', u'to', u'gain', u'knowledge', u'with', u'the', u'trainings', u'provided', u'internally', u'women', u'employee']
# Review :  nice work culture and excellent company, very useful training and learning , user friendly office environment with fun and motive, over all awesome experience
#
# sentence :  nice work culture
# tokenizer : [u'nice', u'work', u'culture']
# removed all non-english words : [u'nice', u'work', u'culture']
#
# sentence : excellent company
# tokenizer : [u'excellent', u'company']
# removed all non-english words : [u'excellent', u'company']
#
# sentence : very useful training
# tokenizer : [u'very', u'useful', u'training']
# removed all non-english words : [u'very', u'useful', u'training']
#
# sentence : learning
# tokenizer : [u'learning']
# removed all non-english words : [u'learning']
#
# sentence : user friendly office environment with fun
# tokenizer : [u'user', u'friendly', u'office', u'environment', u'with', u'fun']
# removed all non-english words : [u'user', u'friendly', u'office', u'environment', u'with', u'fun']
#
# sentence : motive
# tokenizer : [u'motive']
# removed all non-english words : [u'motive']
#
# sentence : over all awesome experience
# tokenizer : [u'over', u'all', u'awesome', u'experience']
# removed all non-english words : [u'over', u'all', u'awesome', u'experience']
# Review :  flexible work nature, work from facility available, multiple technology to work on, horizontal growth, no 9 hours strict swiping, good reputed clients
#
# sentence :  flexible work nature
# tokenizer : [u'flexible', u'work', u'nature']
# removed all non-english words : [u'flexible', u'work', u'nature']
#
# sentence : work from facility available
# tokenizer : [u'work', u'from', u'facility', u'available']
# removed all non-english words : [u'work', u'from', u'facility', u'available']
#
# sentence : multiple technology to work on
# tokenizer : [u'multiple', u'technology', u'to', u'work', u'on']
# removed all non-english words : [u'multiple', u'technology', u'to', u'work', u'on']
#
# sentence : horizontal growth
# tokenizer : [u'horizontal', u'growth']
# removed all non-english words : [u'horizontal', u'growth']
#
# sentence : no 9 hours strict swiping
# tokenizer : [u'no', u'hours', u'strict', u'swiping']
# removed all non-english words : [u'no', u'hours', u'strict', u'swiping']
#
# sentence : good reputed clients
# tokenizer : [u'good', u'reputed', u'clients']
# removed all non-english words : [u'good', u'reputed', u'clients']
# Review :  great experience working with ibm , worked in infrastructure project where i learned and managed 10k windows servers and worked rfs build   projects  , i am working as a 3 rd party pay roll company due to this  i would like quit the job
#
# sentence :  great experience working with ibm
# tokenizer : [u'great', u'experience', u'working', u'with', u'ibm']
# removed all non-english words : [u'great', u'experience', u'working', u'with']
#
# sentence : worked in infrastructure project where i learned
# tokenizer : [u'worked', u'in', u'infrastructure', u'project', u'where', u'i', u'learned']
# removed all non-english words : [u'worked', u'in', u'infrastructure', u'project', u'where', u'i', u'learned']
#
# sentence : managed 10k windows servers
# tokenizer : [u'managed', u'k', u'windows', u'servers']
# removed all non-english words : [u'managed', u'k', u'windows', u'servers']
#
# sentence : worked rfs build   projects
# tokenizer : [u'worked', u'rfs', u'build', u'projects']
# removed all non-english words : [u'worked', u'build', u'projects']
#
# sentence : i am working as a 3 rd party pay roll company due to this  i would like quit the job
# tokenizer : [u'i', u'am', u'working', u'as', u'a', u'rd', u'party', u'pay', u'roll', u'company', u'due', u'to', u'this', u'i', u'would', u'like', u'quit', u'the', u'job']
# removed all non-english words : [u'i', u'am', u'working', u'as', u'a', u'rd', u'party', u'pay', u'roll', u'company', u'due', u'to', u'this', u'i', u'would', u'like', u'quit', u'the', u'job']
# Review :  the overall work culture was satisfactory, there weren't any time restrictions put on by the management, recognition of individual efforts and appreciation,
#
# sentence :  the overall work culture was satisfactory
# tokenizer : [u'the', u'overall', u'work', u'culture', u'was', u'satisfactory']
# removed all non-english words : [u'the', u'overall', u'work', u'culture', u'was', u'satisfactory']
#
# sentence : there weren't any time restrictions put on by the management
# tokenizer : [u'there', u'weren', u't', u'any', u'time', u'restrictions', u'put', u'on', u'by', u'the', u'management']
# removed all non-english words : [u'there', u't', u'any', u'time', u'restrictions', u'put', u'on', u'by', u'the', u'management']
#
# sentence : recognition of individual efforts
# tokenizer : [u'recognition', u'of', u'individual', u'efforts']
# removed all non-english words : [u'recognition', u'of', u'individual', u'efforts']
#
# sentence : appreciation
# tokenizer : [u'appreciation']
# removed all non-english words : [u'appreciation']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  i don't have any comments to add at this moment, none as of now, work culture is great compared to many other companies in this field,  opportunity to work with many global clients,
#
# sentence :  i don't have any comments to add at this moment
# tokenizer : [u'i', u'don', u't', u'have', u'any', u'comments', u'to', u'add', u'at', u'this', u'moment']
# removed all non-english words : [u'i', u'don', u't', u'have', u'any', u'comments', u'to', u'add', u'at', u'this', u'moment']
#
# sentence : none as of now
# tokenizer : [u'none', u'as', u'of', u'now']
# removed all non-english words : [u'none', u'as', u'of', u'now']
#
# sentence : work culture is great compared to many other companies in this field
# tokenizer : [u'work', u'culture', u'is', u'great', u'compared', u'to', u'many', u'other', u'companies', u'in', u'this', u'field']
# removed all non-english words : [u'work', u'culture', u'is', u'great', u'compared', u'to', u'many', u'other', u'companies', u'in', u'this', u'field']
#
# sentence :  opportunity to work with many global clients
# tokenizer : [u'opportunity', u'to', u'work', u'with', u'many', u'global', u'clients']
# removed all non-english words : [u'opportunity', u'to', u'work', u'with', u'many', u'global', u'clients']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  work culture is good and flexible work timings, lot of scope is there to learn new edge technologies like cloud and cognitive, i enjoy working in ibm but for the career advancement have to look for other opportunities,
#
# sentence :  work culture is good
# tokenizer : [u'work', u'culture', u'is', u'good']
# removed all non-english words : [u'work', u'culture', u'is', u'good']
#
# sentence : flexible work timings
# tokenizer : [u'flexible', u'work', u'timings']
# removed all non-english words : [u'flexible', u'work', u'timings']
#
# sentence : lot of scope is there to learn new edge technologies like cloud
# tokenizer : [u'lot', u'of', u'scope', u'is', u'there', u'to', u'learn', u'new', u'edge', u'technologies', u'like', u'cloud']
# removed all non-english words : [u'lot', u'of', u'scope', u'is', u'there', u'to', u'learn', u'new', u'edge', u'technologies', u'like', u'cloud']
#
# sentence : cognitive
# tokenizer : [u'cognitive']
# removed all non-english words : [u'cognitive']
#
# sentence : i enjoy working in ibm
# tokenizer : [u'i', u'enjoy', u'working', u'in', u'ibm']
# removed all non-english words : [u'i', u'enjoy', u'working', u'in']
#
# sentence : for the career advancement have to look for other opportunities
# tokenizer : [u'for', u'the', u'career', u'advancement', u'have', u'to', u'look', u'for', u'other', u'opportunities']
# removed all non-english words : [u'for', u'the', u'career', u'advancement', u'have', u'to', u'look', u'for', u'other', u'opportunities']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  one of the best brands to work for, the most enjoyable part of the job is healthy competition among team members, i have learned so many things as it was my first multi national company experience where we find different work cultures,
#
# sentence :  one of the best brands to work for
# tokenizer : [u'one', u'of', u'the', u'best', u'brands', u'to', u'work', u'for']
# removed all non-english words : [u'one', u'of', u'the', u'best', u'brands', u'to', u'work', u'for']
#
# sentence : the most enjoyable part of the job is healthy competition among team members
# tokenizer : [u'the', u'most', u'enjoyable', u'part', u'of', u'the', u'job', u'is', u'healthy', u'competition', u'among', u'team', u'members']
# removed all non-english words : [u'the', u'most', u'enjoyable', u'part', u'of', u'the', u'job', u'is', u'healthy', u'competition', u'among', u'team', u'members']
#
# sentence : i have learned so many things as it was my first multi national company experience where we find different work cultures
# tokenizer : [u'i', u'have', u'learned', u'so', u'many', u'things', u'as', u'it', u'was', u'my', u'first', u'multi', u'national', u'company', u'experience', u'where', u'we', u'find', u'different', u'work', u'cultures']
# removed all non-english words : [u'i', u'have', u'learned', u'so', u'many', u'things', u'as', u'it', u'was', u'my', u'first', u'multi', u'national', u'company', u'experience', u'where', u'we', u'find', u'different', u'work', u'cultures']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  nice place to work, lots of technologies to learn, nice work life balance, opportunity to work with world at a single place, growth is bit slower thought,
#
# sentence :  nice place to work
# tokenizer : [u'nice', u'place', u'to', u'work']
# removed all non-english words : [u'nice', u'place', u'to', u'work']
#
# sentence : lots of technologies to learn
# tokenizer : [u'lots', u'of', u'technologies', u'to', u'learn']
# removed all non-english words : [u'lots', u'of', u'technologies', u'to', u'learn']
#
# sentence : nice work life balance
# tokenizer : [u'nice', u'work', u'life', u'balance']
# removed all non-english words : [u'nice', u'work', u'life', u'balance']
#
# sentence : opportunity to work with world at a single place
# tokenizer : [u'opportunity', u'to', u'work', u'with', u'world', u'at', u'a', u'single', u'place']
# removed all non-english words : [u'opportunity', u'to', u'work', u'with', u'world', u'at', u'a', u'single', u'place']
#
# sentence : growth is bit slower thought
# tokenizer : [u'growth', u'is', u'bit', u'slower', u'thought']
# removed all non-english words : [u'growth', u'is', u'bit', u'slower', u'thought']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  great place to work,salary wasnt great so had to look out, else wouldn't have wanted to chamge anything about my job, finance teams did  get a lot of opportunity to wfh,
#
# sentence :  great place to work,salary wasnt great so had to look out
# tokenizer : [u'great', u'place', u'to', u'work', u'salary', u'wasnt', u'great', u'so', u'had', u'to', u'look', u'out']
# removed all non-english words : [u'great', u'place', u'to', u'work', u'salary', u'great', u'so', u'had', u'to', u'look', u'out']
#
# sentence : else wouldn't have wanted to chamge anything about my job
# tokenizer : [u'else', u'wouldn', u't', u'have', u'wanted', u'to', u'chamge', u'anything', u'about', u'my', u'job']
# removed all non-english words : [u'else', u't', u'have', u'wanted', u'to', u'anything', u'about', u'my', u'job']
#
# sentence : finance teams did  get a lot of opportunity to wfh
# tokenizer : [u'finance', u'teams', u'did', u'get', u'a', u'lot', u'of', u'opportunity', u'to', u'wfh']
# removed all non-english words : [u'finance', u'teams', u'did', u'get', u'a', u'lot', u'of', u'opportunity', u'to']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  fantastic company to have been a part of, the engineers,  technology, and people are first class,it has great work life balance, very misogynistic company, opportunity to advance only given to those who have been with the company 15+ years, adding to the stagnant culture,
#
# sentence :  fantastic company to have been a part of
# tokenizer : [u'fantastic', u'company', u'to', u'have', u'been', u'a', u'part', u'of']
# removed all non-english words : [u'fantastic', u'company', u'to', u'have', u'been', u'a', u'part', u'of']
#
# sentence : the engineers
# tokenizer : [u'the', u'engineers']
# removed all non-english words : [u'the', u'engineers']
#
# sentence :  technology
# tokenizer : [u'technology']
# removed all non-english words : [u'technology']
#
# sentence : and people are first class,it has great work life balance
# tokenizer : [u'and', u'people', u'are', u'first', u'class', u'it', u'has', u'great', u'work', u'life', u'balance']
# removed all non-english words : [u'and', u'people', u'are', u'first', u'class', u'it', u'has', u'great', u'work', u'life', u'balance']
#
# sentence : very misogynistic company
# tokenizer : [u'very', u'misogynistic', u'company']
# removed all non-english words : [u'very', u'misogynistic', u'company']
#
# sentence : opportunity to advance only given to those who have been with the company 15+ years
# tokenizer : [u'opportunity', u'to', u'advance', u'only', u'given', u'to', u'those', u'who', u'have', u'been', u'with', u'the', u'company', u'years']
# removed all non-english words : [u'opportunity', u'to', u'advance', u'only', u'given', u'to', u'those', u'who', u'have', u'been', u'with', u'the', u'company', u'years']
#
# sentence : adding to the stagnant culture
# tokenizer : [u'adding', u'to', u'the', u'stagnant', u'culture']
# removed all non-english words : [u'adding', u'to', u'the', u'stagnant', u'culture']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  it does just one good - to shower money upon employees, besides this, nothing is good here, an impressive appraisal to worst possible cab facility, this what it is,
#
# sentence :  it does just one good - to shower money upon employees
# tokenizer : [u'it', u'does', u'just', u'one', u'good', u'to', u'shower', u'money', u'upon', u'employees']
# removed all non-english words : [u'it', u'does', u'just', u'one', u'good', u'to', u'shower', u'money', u'upon', u'employees']
#
# sentence : besides this
# tokenizer : [u'besides', u'this']
# removed all non-english words : [u'besides', u'this']
#
# sentence : nothing is good here
# tokenizer : [u'nothing', u'is', u'good', u'here']
# removed all non-english words : [u'nothing', u'is', u'good', u'here']
#
# sentence : an impressive appraisal to worst possible cab facility
# tokenizer : [u'an', u'impressive', u'appraisal', u'to', u'worst', u'possible', u'cab', u'facility']
# removed all non-english words : [u'an', u'impressive', u'appraisal', u'to', u'worst', u'possible', u'cab', u'facility']
#
# sentence : this what it is
# tokenizer : [u'this', u'what', u'it', u'is']
# removed all non-english words : [u'this', u'what', u'it', u'is']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  good work place, a place where you can learn and apply your concepts, great team meeting and team activities to build self confidence in employee, good place to learn new things,
#
# sentence :  good work place
# tokenizer : [u'good', u'work', u'place']
# removed all non-english words : [u'good', u'work', u'place']
#
# sentence : a place where you can learn
# tokenizer : [u'a', u'place', u'where', u'you', u'can', u'learn']
# removed all non-english words : [u'a', u'place', u'where', u'you', u'can', u'learn']
#
# sentence : apply your concepts
# tokenizer : [u'apply', u'your', u'concepts']
# removed all non-english words : [u'apply', u'your', u'concepts']
#
# sentence : great team meeting
# tokenizer : [u'great', u'team', u'meeting']
# removed all non-english words : [u'great', u'team', u'meeting']
#
# sentence : team activities to build self confidence in employee
# tokenizer : [u'team', u'activities', u'to', u'build', u'self', u'confidence', u'in', u'employee']
# removed all non-english words : [u'team', u'activities', u'to', u'build', u'self', u'confidence', u'in', u'employee']
#
# sentence : good place to learn new things
# tokenizer : [u'good', u'place', u'to', u'learn', u'new', u'things']
# removed all non-english words : [u'good', u'place', u'to', u'learn', u'new', u'things']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  work from home is the best option at ibm, but incentives are less in ibm compared to other companies, work life balance is ok but not so successful, extended hours may require,
#
# sentence :  work from home is the best option at ibm
# tokenizer : [u'work', u'from', u'home', u'is', u'the', u'best', u'option', u'at', u'ibm']
# removed all non-english words : [u'work', u'from', u'home', u'is', u'the', u'best', u'option', u'at']
#
# sentence : but incentives are less in ibm compared to other companies
# tokenizer : [u'but', u'incentives', u'are', u'less', u'in', u'ibm', u'compared', u'to', u'other', u'companies']
# removed all non-english words : [u'but', u'incentives', u'are', u'less', u'in', u'compared', u'to', u'other', u'companies']
#
# sentence : work life balance is ok
# tokenizer : [u'work', u'life', u'balance', u'is', u'ok']
# removed all non-english words : [u'work', u'life', u'balance', u'is']
#
# sentence : not so successful
# tokenizer : [u'not', u'so', u'successful']
# removed all non-english words : [u'not', u'so', u'successful']
#
# sentence : extended hours may require
# tokenizer : [u'extended', u'hours', u'may', u'require']
# removed all non-english words : [u'extended', u'hours', u'may', u'require']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  good place to work with great balancing of work and personal life as work from home options are available,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# sentence :  good place to work with great balancing of work
# tokenizer : [u'good', u'place', u'to', u'work', u'with', u'great', u'balancing', u'of', u'work']
# removed all non-english words : [u'good', u'place', u'to', u'work', u'with', u'great', u'balancing', u'of', u'work']
#
# sentence : personal life as work from home options are available,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# tokenizer : [u'personal', u'life', u'as', u'work', u'from', u'home', u'options', u'are', u'available']
# removed all non-english words : [u'personal', u'life', u'as', u'work', u'from', u'home', u'options', u'are', u'available']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  good branded it company with international recognition, excellent culture with flexibility of work from home,  very good place for folks with managers designation and above,
#
# sentence :  good branded it company with international recognition
# tokenizer : [u'good', u'branded', u'it', u'company', u'with', u'international', u'recognition']
# removed all non-english words : [u'good', u'branded', u'it', u'company', u'with', u'international', u'recognition']
#
# sentence : excellent culture with flexibility of work from home
# tokenizer : [u'excellent', u'culture', u'with', u'flexibility', u'of', u'work', u'from', u'home']
# removed all non-english words : [u'excellent', u'culture', u'with', u'flexibility', u'of', u'work', u'from', u'home']
#
# sentence :  very good place for folks with managers designation
# tokenizer : [u'very', u'good', u'place', u'for', u'folks', u'with', u'managers', u'designation']
# removed all non-english words : [u'very', u'good', u'place', u'for', u'folks', u'with', u'managers', u'designation']
#
# sentence : above
# tokenizer : [u'above']
# removed all non-english words : [u'above']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  ibm is a company with 100 years of background, working in ibm will give you lot of exposure to processes and routines, it is a great place to learn and a lot of opportunities to take their career to the next level
#
# sentence :  ibm is a company with 100 years of background
# tokenizer : [u'ibm', u'is', u'a', u'company', u'with', u'years', u'of', u'background']
# removed all non-english words : [u'is', u'a', u'company', u'with', u'years', u'of', u'background']
#
# sentence : working in ibm will give you lot of exposure to processes
# tokenizer : [u'working', u'in', u'ibm', u'will', u'give', u'you', u'lot', u'of', u'exposure', u'to', u'processes']
# removed all non-english words : [u'working', u'in', u'will', u'give', u'you', u'lot', u'of', u'exposure', u'to', u'processes']
#
# sentence : routines
# tokenizer : [u'routines']
# removed all non-english words : [u'routines']
#
# sentence : it is a great place to learn
# tokenizer : [u'it', u'is', u'a', u'great', u'place', u'to', u'learn']
# removed all non-english words : [u'it', u'is', u'a', u'great', u'place', u'to', u'learn']
#
# sentence : a lot of opportunities to take their career to the next level
# tokenizer : [u'a', u'lot', u'of', u'opportunities', u'to', u'take', u'their', u'career', u'to', u'the', u'next', u'level']
# removed all non-english words : [u'a', u'lot', u'of', u'opportunities', u'to', u'take', u'their', u'career', u'to', u'the', u'next', u'level']
# Review :  ibm provides immense opportunities to its employees in terms of career opportunities, with its global presence ibm is an international brand which has the potential to attract talents all across the globe
#
# sentence :  ibm provides immense opportunities to its employees in terms of career opportunities
# tokenizer : [u'ibm', u'provides', u'immense', u'opportunities', u'to', u'its', u'employees', u'in', u'terms', u'of', u'career', u'opportunities']
# removed all non-english words : [u'provides', u'immense', u'opportunities', u'to', u'its', u'employees', u'in', u'terms', u'of', u'career', u'opportunities']
#
# sentence : with its global presence ibm is an international brand which has the potential to attract talents all across the globe
# tokenizer : [u'with', u'its', u'global', u'presence', u'ibm', u'is', u'an', u'international', u'brand', u'which', u'has', u'the', u'potential', u'to', u'attract', u'talents', u'all', u'across', u'the', u'globe']
# removed all non-english words : [u'with', u'its', u'global', u'presence', u'is', u'an', u'international', u'brand', u'which', u'has', u'the', u'potential', u'to', u'attract', u'talents', u'all', u'across', u'the', u'globe']
# Review :  they have the one of the best insurance policies,  also the reimbursement policies are better than many service industry companies,  if you are not bogged down by the pay factor, which is almost the same with any service company sending people to onsite, it is a decent organization to work for,  another major factor to work for ibm india in onsite is the leave policy, they have one of the most lenient leave policies and practically limitless sick leaves, i bet no other company does that,
#
# sentence :  they have the one of the best insurance policies
# tokenizer : [u'they', u'have', u'the', u'one', u'of', u'the', u'best', u'insurance', u'policies']
# removed all non-english words : [u'they', u'have', u'the', u'one', u'of', u'the', u'best', u'insurance', u'policies']
#
# sentence :  also the reimbursement policies are better than many service industry companies
# tokenizer : [u'also', u'the', u'reimbursement', u'policies', u'are', u'better', u'than', u'many', u'service', u'industry', u'companies']
# removed all non-english words : [u'also', u'the', u'reimbursement', u'policies', u'are', u'better', u'than', u'many', u'service', u'industry', u'companies']
#
# sentence :  if you are not bogged down by the pay factor
# tokenizer : [u'if', u'you', u'are', u'not', u'bogged', u'down', u'by', u'the', u'pay', u'factor']
# removed all non-english words : [u'if', u'you', u'are', u'not', u'bogged', u'down', u'by', u'the', u'pay', u'factor']
#
# sentence : which is almost the same with any service company sending people to onsite
# tokenizer : [u'which', u'is', u'almost', u'the', u'same', u'with', u'any', u'service', u'company', u'sending', u'people', u'to', u'onsite']
# removed all non-english words : [u'which', u'is', u'almost', u'the', u'same', u'with', u'any', u'service', u'company', u'sending', u'people', u'to']
#
# sentence : it is a decent organization to work for
# tokenizer : [u'it', u'is', u'a', u'decent', u'organization', u'to', u'work', u'for']
# removed all non-english words : [u'it', u'is', u'a', u'decent', u'organization', u'to', u'work', u'for']
#
# sentence :  another major factor to work for ibm india in onsite is the leave policy
# tokenizer : [u'another', u'major', u'factor', u'to', u'work', u'for', u'ibm', u'india', u'in', u'onsite', u'is', u'the', u'leave', u'policy']
# removed all non-english words : [u'another', u'major', u'factor', u'to', u'work', u'for', u'in', u'is', u'the', u'leave', u'policy']
#
# sentence : they have one of the most lenient leave policies
# tokenizer : [u'they', u'have', u'one', u'of', u'the', u'most', u'lenient', u'leave', u'policies']
# removed all non-english words : [u'they', u'have', u'one', u'of', u'the', u'most', u'lenient', u'leave', u'policies']
#
# sentence : practically limitless sick leaves
# tokenizer : [u'practically', u'limitless', u'sick', u'leaves']
# removed all non-english words : [u'practically', u'limitless', u'sick', u'leaves']
#
# sentence : i bet no other company does that
# tokenizer : [u'i', u'bet', u'no', u'other', u'company', u'does', u'that']
# removed all non-english words : [u'i', u'bet', u'no', u'other', u'company', u'does', u'that']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  dont join this company because they dont treat you like an employee  as i have been there as a contractor, there were many partialities over regular employees
#
# sentence :  dont join this company because they dont treat you like an employee  as i have been there as a contractor
# tokenizer : [u'dont', u'join', u'this', u'company', u'because', u'they', u'dont', u'treat', u'you', u'like', u'an', u'employee', u'as', u'i', u'have', u'been', u'there', u'as', u'a', u'contractor']
# removed all non-english words : [u'join', u'this', u'company', u'because', u'they', u'treat', u'you', u'like', u'an', u'employee', u'as', u'i', u'have', u'been', u'there', u'as', u'a', u'contractor']
#
# sentence : there were many partialities over regular employees
# tokenizer : [u'there', u'were', u'many', u'partialities', u'over', u'regular', u'employees']
# removed all non-english words : [u'there', u'were', u'many', u'partialities', u'over', u'regular', u'employees']
# Review :  a good place to learn different tools and different technologies   work culture is always good, the best part of ibm is work flexibility like work from home can sit any place in iibm and can work
#
# sentence :  a good place to learn different tools
# tokenizer : [u'a', u'good', u'place', u'to', u'learn', u'different', u'tools']
# removed all non-english words : [u'a', u'good', u'place', u'to', u'learn', u'different', u'tools']
#
# sentence : different technologies   work culture is always good
# tokenizer : [u'different', u'technologies', u'work', u'culture', u'is', u'always', u'good']
# removed all non-english words : [u'different', u'technologies', u'work', u'culture', u'is', u'always', u'good']
#
# sentence : the best part of ibm is work flexibility like work from home can sit any place in iibm
# tokenizer : [u'the', u'best', u'part', u'of', u'ibm', u'is', u'work', u'flexibility', u'like', u'work', u'from', u'home', u'can', u'sit', u'any', u'place', u'in', u'iibm']
# removed all non-english words : [u'the', u'best', u'part', u'of', u'is', u'work', u'flexibility', u'like', u'work', u'from', u'home', u'can', u'sit', u'any', u'place', u'in']
#
# sentence : can work
# tokenizer : [u'can', u'work']
# removed all non-english words : [u'can', u'work']
# Review :  growing up the ladder in the technology perspective is good, ibm will give you lot of work / life balance, work from home is the best thing that i have seen in ibm
#
# sentence :  growing up the ladder in the technology perspective is good
# tokenizer : [u'growing', u'up', u'the', u'ladder', u'in', u'the', u'technology', u'perspective', u'is', u'good']
# removed all non-english words : [u'growing', u'up', u'the', u'ladder', u'in', u'the', u'technology', u'perspective', u'is', u'good']
#
# sentence : ibm will give you lot of work / life balance
# tokenizer : [u'ibm', u'will', u'give', u'you', u'lot', u'of', u'work', u'life', u'balance']
# removed all non-english words : [u'will', u'give', u'you', u'lot', u'of', u'work', u'life', u'balance']
#
# sentence : work from home is the best thing that i have seen in ibm
# tokenizer : [u'work', u'from', u'home', u'is', u'the', u'best', u'thing', u'that', u'i', u'have', u'seen', u'in', u'ibm']
# removed all non-english words : [u'work', u'from', u'home', u'is', u'the', u'best', u'thing', u'that', u'i', u'have', u'seen', u'in']
# Review :  this is a very good company for work,their work environment is very good,people are very good and always help to learn new things, i have learnt so many new things, this will help me to express myself ,
#
# sentence :  this is a very good company for work,their work environment is very good,people are very good
# tokenizer : [u'this', u'is', u'a', u'very', u'good', u'company', u'for', u'work', u'their', u'work', u'environment', u'is', u'very', u'good', u'people', u'are', u'very', u'good']
# removed all non-english words : [u'this', u'is', u'a', u'very', u'good', u'company', u'for', u'work', u'their', u'work', u'environment', u'is', u'very', u'good', u'people', u'are', u'very', u'good']
#
# sentence : always help to learn new things
# tokenizer : [u'always', u'help', u'to', u'learn', u'new', u'things']
# removed all non-english words : [u'always', u'help', u'to', u'learn', u'new', u'things']
#
# sentence : i have learnt so many new things
# tokenizer : [u'i', u'have', u'learnt', u'so', u'many', u'new', u'things']
# removed all non-english words : [u'i', u'have', u'so', u'many', u'new', u'things']
#
# sentence : this will help me to express myself
# tokenizer : [u'this', u'will', u'help', u'me', u'to', u'express', u'myself']
# removed all non-english words : [u'this', u'will', u'help', u'me', u'to', u'express', u'myself']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  work life balance is great but salary, increment &amp; job security side is worst, work from home option is good during vacation and emergency periods,,,,,
#
# sentence :  work life balance is great
# tokenizer : [u'work', u'life', u'balance', u'is', u'great']
# removed all non-english words : [u'work', u'life', u'balance', u'is', u'great']
#
# sentence : salary
# tokenizer : [u'salary']
# removed all non-english words : [u'salary']
#
# sentence : increment &amp; job security side is worst
# tokenizer : [u'increment', u'amp', u'job', u'security', u'side', u'is', u'worst']
# removed all non-english words : [u'increment', u'amp', u'job', u'security', u'side', u'is', u'worst']
#
# sentence : work from home option is good during vacation
# tokenizer : [u'work', u'from', u'home', u'option', u'is', u'good', u'during', u'vacation']
# removed all non-english words : [u'work', u'from', u'home', u'option', u'is', u'good', u'during', u'vacation']
#
# sentence : emergency periods,,,,
# tokenizer : [u'emergency', u'periods']
# removed all non-english words : [u'emergency', u'periods']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  this place has inconsistent salary hikes year on year, for few years, the salary hikes are as low as 1% on an average, once in 5 years they give a sudden hike which confuses all employees,
#
# sentence :  this place has inconsistent salary hikes year on year
# tokenizer : [u'this', u'place', u'has', u'inconsistent', u'salary', u'hikes', u'year', u'on', u'year']
# removed all non-english words : [u'this', u'place', u'has', u'inconsistent', u'salary', u'hikes', u'year', u'on', u'year']
#
# sentence : for few years
# tokenizer : [u'for', u'few', u'years']
# removed all non-english words : [u'for', u'few', u'years']
#
# sentence : the salary hikes are as low as 1% on an average
# tokenizer : [u'the', u'salary', u'hikes', u'are', u'as', u'low', u'as', u'on', u'an', u'average']
# removed all non-english words : [u'the', u'salary', u'hikes', u'are', u'as', u'low', u'as', u'on', u'an', u'average']
#
# sentence : once in 5 years they give a sudden hike which confuses all employees
# tokenizer : [u'once', u'in', u'years', u'they', u'give', u'a', u'sudden', u'hike', u'which', u'confuses', u'all', u'employees']
# removed all non-english words : [u'once', u'in', u'years', u'they', u'give', u'a', u'sudden', u'hike', u'which', u'confuses', u'all', u'employees']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  great manager and great business unit where i had an opportunity to learn a lot,workplace was always fun and cheerful , there was good managing operations,
#
# sentence :  great manager
# tokenizer : [u'great', u'manager']
# removed all non-english words : [u'great', u'manager']
#
# sentence : great business unit where i had an opportunity to learn a lot,workplace was always fun
# tokenizer : [u'great', u'business', u'unit', u'where', u'i', u'had', u'an', u'opportunity', u'to', u'learn', u'a', u'lot', u'workplace', u'was', u'always', u'fun']
# removed all non-english words : [u'great', u'business', u'unit', u'where', u'i', u'had', u'an', u'opportunity', u'to', u'learn', u'a', u'lot', u'workplace', u'was', u'always', u'fun']
#
# sentence : cheerful
# tokenizer : [u'cheerful']
# removed all non-english words : [u'cheerful']
#
# sentence : there was good managing operations
# tokenizer : [u'there', u'was', u'good', u'managing', u'operations']
# removed all non-english words : [u'there', u'was', u'good', u'managing', u'operations']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  productive and fun place to work, fast paced environment, professional environment, managers are friendly and helpful,  freedom to learn and implement in workplace,
#
# sentence :  productive
# tokenizer : [u'productive']
# removed all non-english words : [u'productive']
#
# sentence : fun place to work
# tokenizer : [u'fun', u'place', u'to', u'work']
# removed all non-english words : [u'fun', u'place', u'to', u'work']
#
# sentence : fast paced environment
# tokenizer : [u'fast', u'paced', u'environment']
# removed all non-english words : [u'fast', u'paced', u'environment']
#
# sentence : professional environment
# tokenizer : [u'professional', u'environment']
# removed all non-english words : [u'professional', u'environment']
#
# sentence : managers are friendly
# tokenizer : [u'managers', u'are', u'friendly']
# removed all non-english words : [u'managers', u'are', u'friendly']
#
# sentence : helpful
# tokenizer : [u'helpful']
# removed all non-english words : [u'helpful']
#
# sentence :  freedom to learn
# tokenizer : [u'freedom', u'to', u'learn']
# removed all non-english words : [u'freedom', u'to', u'learn']
#
# sentence : implement in workplace
# tokenizer : [u'implement', u'in', u'workplace']
# removed all non-english words : [u'implement', u'in', u'workplace']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  i enjoyed working in ibm, its a very good company which takes care of its employees like we do have facilities in case of personal issues- unlimited sick leaves, loa, good time breaks, work culture is very good and you get a good work to learn here, seniors help a lot in each and every task,
#
# sentence :  i enjoyed working in ibm
# tokenizer : [u'i', u'enjoyed', u'working', u'in', u'ibm']
# removed all non-english words : [u'i', u'enjoyed', u'working', u'in']
#
# sentence : its a very good company which takes care of its employees like we do have facilities in case of personal issues- unlimited sick leaves
# tokenizer : [u'its', u'a', u'very', u'good', u'company', u'which', u'takes', u'care', u'of', u'its', u'employees', u'like', u'we', u'do', u'have', u'facilities', u'in', u'case', u'of', u'personal', u'issues', u'unlimited', u'sick', u'leaves']
# removed all non-english words : [u'its', u'a', u'very', u'good', u'company', u'which', u'takes', u'care', u'of', u'its', u'employees', u'like', u'we', u'do', u'have', u'facilities', u'in', u'case', u'of', u'personal', u'issues', u'unlimited', u'sick', u'leaves']
#
# sentence : loa
# tokenizer : [u'loa']
# removed all non-english words : []
#
# sentence : good time breaks
# tokenizer : [u'good', u'time', u'breaks']
# removed all non-english words : [u'good', u'time', u'breaks']
#
# sentence : work culture is very good
# tokenizer : [u'work', u'culture', u'is', u'very', u'good']
# removed all non-english words : [u'work', u'culture', u'is', u'very', u'good']
#
# sentence : you get a good work to learn here
# tokenizer : [u'you', u'get', u'a', u'good', u'work', u'to', u'learn', u'here']
# removed all non-english words : [u'you', u'get', u'a', u'good', u'work', u'to', u'learn', u'here']
#
# sentence : seniors help a lot in each
# tokenizer : [u'seniors', u'help', u'a', u'lot', u'in', u'each']
# removed all non-english words : [u'seniors', u'help', u'a', u'lot', u'in', u'each']
#
# sentence : every task
# tokenizer : [u'every', u'task']
# removed all non-english words : [u'every', u'task']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  since the process where i was working was a newly transitioned process so it had a lot of challenges as there was a high pressure of meeting client's expectations, though the organization is very structured and good firm to work with,
#
# sentence :  since the process where i was working was a newly transitioned process so it had a lot of challenges as there was a high pressure of meeting client's expectations
# tokenizer : [u'since', u'the', u'process', u'where', u'i', u'was', u'working', u'was', u'a', u'newly', u'transitioned', u'process', u'so', u'it', u'had', u'a', u'lot', u'of', u'challenges', u'as', u'there', u'was', u'a', u'high', u'pressure', u'of', u'meeting', u'client', u's', u'expectations']
# removed all non-english words : [u'since', u'the', u'process', u'where', u'i', u'was', u'working', u'was', u'a', u'newly', u'transitioned', u'process', u'so', u'it', u'had', u'a', u'lot', u'of', u'challenges', u'as', u'there', u'was', u'a', u'high', u'pressure', u'of', u'meeting', u'client', u's', u'expectations']
#
# sentence : though the organization is very structured
# tokenizer : [u'though', u'the', u'organization', u'is', u'very', u'structured']
# removed all non-english words : [u'though', u'the', u'organization', u'is', u'very', u'structured']
#
# sentence : good firm to work with
# tokenizer : [u'good', u'firm', u'to', u'work', u'with']
# removed all non-english words : [u'good', u'firm', u'to', u'work', u'with']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  at ibm, work flexibility is there and learned lot of things that helped in improving my skills while working, working at this company give me very pleasure and would like to work again,
#
# sentence :  at ibm
# tokenizer : [u'at', u'ibm']
# removed all non-english words : [u'at']
#
# sentence : work flexibility is there
# tokenizer : [u'work', u'flexibility', u'is', u'there']
# removed all non-english words : [u'work', u'flexibility', u'is', u'there']
#
# sentence : learned lot of things that helped in improving my skills while working
# tokenizer : [u'learned', u'lot', u'of', u'things', u'that', u'helped', u'in', u'improving', u'my', u'skills', u'while', u'working']
# removed all non-english words : [u'learned', u'lot', u'of', u'things', u'that', u'helped', u'in', u'improving', u'my', u'skills', u'while', u'working']
#
# sentence : working at this company give me very pleasure
# tokenizer : [u'working', u'at', u'this', u'company', u'give', u'me', u'very', u'pleasure']
# removed all non-english words : [u'working', u'at', u'this', u'company', u'give', u'me', u'very', u'pleasure']
#
# sentence : would like to work again
# tokenizer : [u'would', u'like', u'to', u'work', u'again']
# removed all non-english words : [u'would', u'like', u'to', u'work', u'again']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  nice environment happy to be a ibmer 😊 working in this company is good , provide friendly environment  and women's safety also , not much pressure given by managers,
#
# sentence :  nice environment happy to be a ibmer 😊 working in this company is good
# tokenizer : [u'nice', u'environment', u'happy', u'to', u'be', u'a', u'ibmer', u'working', u'in', u'this', u'company', u'is', u'good']
# removed all non-english words : [u'nice', u'environment', u'happy', u'to', u'be', u'a', u'working', u'in', u'this', u'company', u'is', u'good']
#
# sentence : provide friendly environment
# tokenizer : [u'provide', u'friendly', u'environment']
# removed all non-english words : [u'provide', u'friendly', u'environment']
#
# sentence : women's safety also
# tokenizer : [u'women', u's', u'safety', u'also']
# removed all non-english words : [u'women', u's', u'safety', u'also']
#
# sentence : not much pressure given by managers
# tokenizer : [u'not', u'much', u'pressure', u'given', u'by', u'managers']
# removed all non-english words : [u'not', u'much', u'pressure', u'given', u'by', u'managers']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  i have learned many things at ibm and great place to work on such a big origination,   i even learn management skill too,and they way i got training related to my current job role helped a lot
#
# sentence :  i have learned many things at ibm
# tokenizer : [u'i', u'have', u'learned', u'many', u'things', u'at', u'ibm']
# removed all non-english words : [u'i', u'have', u'learned', u'many', u'things', u'at']
#
# sentence : great place to work on such a big origination
# tokenizer : [u'great', u'place', u'to', u'work', u'on', u'such', u'a', u'big', u'origination']
# removed all non-english words : [u'great', u'place', u'to', u'work', u'on', u'such', u'a', u'big', u'origination']
#
# sentence :   i even learn management skill too,and they way i got training related to my current job role helped a lot
# tokenizer : [u'i', u'even', u'learn', u'management', u'skill', u'too', u'and', u'they', u'way', u'i', u'got', u'training', u'related', u'to', u'my', u'current', u'job', u'role', u'helped', u'a', u'lot']
# removed all non-english words : [u'i', u'even', u'learn', u'management', u'skill', u'too', u'and', u'they', u'way', u'i', u'got', u'training', u'related', u'to', u'my', u'current', u'job', u'role', u'helped', u'a', u'lot']
# Review :  i am proud of being part of 100 years old company, did account management there,great place to work,  no pressure and work culture is good,  ibm provided lots of flexibility to their employees,  descent pay masters :)
#
# ...
# tokenizer : [u'my', u'job', u'profile', u'was', u'to', u'resolve', u'the', u'customer', u'queries', u'through', u'e', u'mailing']
# removed all non-english words : [u'my', u'job', u'profile', u'was', u'to', u'resolve', u'the', u'customer', u'queries', u'through', u'e', u'mailing']
#
# sentence :  i learned how to work in a team
# tokenizer : [u'i', u'learned', u'how', u'to', u'work', u'in', u'a', u'team']
# removed all non-english words : [u'i', u'learned', u'how', u'to', u'work', u'in', u'a', u'team']
#
# sentence : achieve the organisation goal
# tokenizer : [u'achieve', u'the', u'organisation', u'goal']
# removed all non-english words : [u'achieve', u'the', u'goal']
#
# sentence :  the management of ibm is well organised
# tokenizer : [u'the', u'management', u'of', u'ibm', u'is', u'well', u'organised']
# removed all non-english words : [u'the', u'management', u'of', u'is', u'well']
#
# sentence : ibm values their employees
# tokenizer : [u'ibm', u'values', u'their', u'employees']
# removed all non-english words : [u'values', u'their', u'employees']
#
# sentence :   ibm hires the educated candidates
# tokenizer : [u'ibm', u'hires', u'the', u'educated', u'candidates']
# removed all non-english words : [u'hires', u'the', u'educated', u'candidates']
#
# sentence : employees are well behaved
# tokenizer : [u'employees', u'are', u'well', u'behaved']
# removed all non-english words : [u'employees', u'are', u'well', u'behaved']
#
# sentence : job responsible
# tokenizer : [u'job', u'responsible']
# removed all non-english words : [u'job', u'responsible']
#
# sentence :  the hardest part of the job was rotation shifts
# tokenizer : [u'the', u'hardest', u'part', u'of', u'the', u'job', u'was', u'rotation', u'shifts']
# removed all non-english words : [u'the', u'hardest', u'part', u'of', u'the', u'job', u'was', u'rotation', u'shifts']
#
# sentence : it was hard to work in nights
# tokenizer : [u'it', u'was', u'hard', u'to', u'work', u'in', u'nights']
# removed all non-english words : [u'it', u'was', u'hard', u'to', u'work', u'in', u'nights']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  located in nice location, good place to work, work pressure is comparatively less and completely process oriented company
#
# sentence :  located in nice location
# tokenizer : [u'located', u'in', u'nice', u'location']
# removed all non-english words : [u'located', u'in', u'nice', u'location']
#
# sentence : good place to work
# tokenizer : [u'good', u'place', u'to', u'work']
# removed all non-english words : [u'good', u'place', u'to', u'work']
#
# sentence : work pressure is comparatively less
# tokenizer : [u'work', u'pressure', u'is', u'comparatively', u'less']
# removed all non-english words : [u'work', u'pressure', u'is', u'comparatively', u'less']
#
# sentence : completely process oriented company
# tokenizer : [u'completely', u'process', u'oriented', u'company']
# removed all non-english words : [u'completely', u'process', u'oriented', u'company']
# Review :  recommended work to improve skills and technicalities,  focal and smes are helpful and all associates are very competitive which is a good thing to work and the rank and limit can be measured,
#
# sentence :  recommended work to improve skills
# tokenizer : [u'recommended', u'work', u'to', u'improve', u'skills']
# removed all non-english words : [u'recommended', u'work', u'to', u'improve', u'skills']
#
# sentence : technicalities
# tokenizer : [u'technicalities']
# removed all non-english words : [u'technicalities']
#
# sentence :  focal
# tokenizer : [u'focal']
# removed all non-english words : [u'focal']
#
# sentence : smes are helpful
# tokenizer : [u'smes', u'are', u'helpful']
# removed all non-english words : [u'are', u'helpful']
#
# sentence : all associates are very competitive which is a good thing to work
# tokenizer : [u'all', u'associates', u'are', u'very', u'competitive', u'which', u'is', u'a', u'good', u'thing', u'to', u'work']
# removed all non-english words : [u'all', u'associates', u'are', u'very', u'competitive', u'which', u'is', u'a', u'good', u'thing', u'to', u'work']
#
# sentence : the rank
# tokenizer : [u'the', u'rank']
# removed all non-english words : [u'the', u'rank']
#
# sentence : limit can be measured
# tokenizer : [u'limit', u'can', u'be', u'measured']
# removed all non-english words : [u'limit', u'can', u'be', u'measured']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  when i joined the company strength was around 100 within very short span 1 year it increased strength to 5000, motivational and flexible to work, performance oriented company, cultural activities and fun at work,
#
# sentence :  when i joined the company strength was around 100 within very short span 1 year it increased strength to 5000
# tokenizer : [u'when', u'i', u'joined', u'the', u'company', u'strength', u'was', u'around', u'within', u'very', u'short', u'span', u'year', u'it', u'increased', u'strength', u'to']
# removed all non-english words : [u'when', u'i', u'joined', u'the', u'company', u'strength', u'was', u'around', u'within', u'very', u'short', u'span', u'year', u'it', u'increased', u'strength', u'to']
#
# sentence : motivational
# tokenizer : [u'motivational']
# removed all non-english words : [u'motivational']
#
# sentence : flexible to work
# tokenizer : [u'flexible', u'to', u'work']
# removed all non-english words : [u'flexible', u'to', u'work']
#
# sentence : performance oriented company
# tokenizer : [u'performance', u'oriented', u'company']
# removed all non-english words : [u'performance', u'oriented', u'company']
#
# sentence : cultural activities
# tokenizer : [u'cultural', u'activities']
# removed all non-english words : [u'cultural', u'activities']
#
# sentence : fun at work
# tokenizer : [u'fun', u'at', u'work']
# removed all non-english words : [u'fun', u'at', u'work']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  ibm has an amazing pool of talent, and a vast portfolio of patents and innovations, that matter, and it does amazing things all the time,   it is a safe place to work and a great place to get experience,    best work culture more leaves compared to other companies (paid sick leave) most important!! less politics compared to other companies many prestigious clients good on-site opportunities office working hours not recorded (flexible timings) good travel/re-location reimbursement policies
#
# sentence :  ibm has an amazing pool of talent
# tokenizer : [u'ibm', u'has', u'an', u'amazing', u'pool', u'of', u'talent']
# removed all non-english words : [u'has', u'an', u'amazing', u'pool', u'of', u'talent']
#
# sentence : and a vast portfolio of patents
# tokenizer : [u'and', u'a', u'vast', u'portfolio', u'of', u'patents']
# removed all non-english words : [u'and', u'a', u'vast', u'portfolio', u'of', u'patents']
#
# sentence : innovations
# tokenizer : [u'innovations']
# removed all non-english words : [u'innovations']
#
# sentence : that matter
# tokenizer : [u'that', u'matter']
# removed all non-english words : [u'that', u'matter']
#
# sentence : and it does amazing things all the time
# tokenizer : [u'and', u'it', u'does', u'amazing', u'things', u'all', u'the', u'time']
# removed all non-english words : [u'and', u'it', u'does', u'amazing', u'things', u'all', u'the', u'time']
#
# sentence :   it is a safe place to work
# tokenizer : [u'it', u'is', u'a', u'safe', u'place', u'to', u'work']
# removed all non-english words : [u'it', u'is', u'a', u'safe', u'place', u'to', u'work']
#
# sentence : a great place to get experience
# tokenizer : [u'a', u'great', u'place', u'to', u'get', u'experience']
# removed all non-english words : [u'a', u'great', u'place', u'to', u'get', u'experience']
#
# sentence :    best work culture more leaves compared to other companies (paid sick leave) most important!! less politics compared to other companies many prestigious clients good on-site opportunities office working hours not recorded (flexible timings) good travel/re-location reimbursement policies
# tokenizer : [u'best', u'work', u'culture', u'more', u'leaves', u'compared', u'to', u'other', u'companies', u'paid', u'sick', u'leave', u'most', u'important', u'less', u'politics', u'compared', u'to', u'other', u'companies', u'many', u'prestigious', u'clients', u'good', u'on', u'site', u'opportunities', u'office', u'working', u'hours', u'not', u'recorded', u'flexible', u'timings', u'good', u'travel', u're', u'location', u'reimbursement', u'policies']
# removed all non-english words : [u'best', u'work', u'culture', u'more', u'leaves', u'compared', u'to', u'other', u'companies', u'paid', u'sick', u'leave', u'most', u'important', u'less', u'politics', u'compared', u'to', u'other', u'companies', u'many', u'prestigious', u'clients', u'good', u'on', u'site', u'opportunities', u'office', u'working', u'hours', u'not', u'recorded', u'flexible', u'timings', u'good', u'travel', u're', u'location', u'reimbursement', u'policies']
# Review :  &gt;in ibm- i worked for 2,5 years, i didnt find a typical day becoz of everyone will be a supportive in work if i would have faced any kind of issue, &gt;completing the work as per the timelines &amp; adaptive to the client requirements, &gt;about management, i can say the best management in my experience, &gt;co-workers, like different collegues have a different way of thinking and overall, all of the ibmers are in creative thinking platform, &gt; hardest part of my job &amp; as well as in my professional carrier is, leaving the ibm- wish to comeback and i am trying the same at present, &gt;when i got a gem award,
#
# sentence :  &gt;in ibm- i worked for 2,5 years
# tokenizer : [u'gt', u'in', u'ibm', u'i', u'worked', u'for', u'years']
# removed all non-english words : [u'gt', u'in', u'i', u'worked', u'for', u'years']
#
# sentence : i didnt find a typical day becoz of everyone will be a supportive in work if i would have faced any kind of issue
# tokenizer : [u'i', u'didnt', u'find', u'a', u'typical', u'day', u'becoz', u'of', u'everyone', u'will', u'be', u'a', u'supportive', u'in', u'work', u'if', u'i', u'would', u'have', u'faced', u'any', u'kind', u'of', u'issue']
# removed all non-english words : [u'i', u'find', u'a', u'typical', u'day', u'of', u'everyone', u'will', u'be', u'a', u'supportive', u'in', u'work', u'if', u'i', u'would', u'have', u'faced', u'any', u'kind', u'of', u'issue']
#
# sentence : &gt;completing the work as per the timelines &amp; adaptive to the client requirements
# tokenizer : [u'gt', u'completing', u'the', u'work', u'as', u'per', u'the', u'timelines', u'amp', u'adaptive', u'to', u'the', u'client', u'requirements']
# removed all non-english words : [u'gt', u'completing', u'the', u'work', u'as', u'per', u'the', u'amp', u'adaptive', u'to', u'the', u'client', u'requirements']
#
# sentence : &gt;about management
# tokenizer : [u'gt', u'about', u'management']
# removed all non-english words : [u'gt', u'about', u'management']
#
# sentence : i can say the best management in my experience
# tokenizer : [u'i', u'can', u'say', u'the', u'best', u'management', u'in', u'my', u'experience']
# removed all non-english words : [u'i', u'can', u'say', u'the', u'best', u'management', u'in', u'my', u'experience']
#
# sentence : &gt;co-workers
# tokenizer : [u'gt', u'co', u'workers']
# removed all non-english words : [u'gt', u'co', u'workers']
#
# sentence : like different collegues have a different way of thinking
# tokenizer : [u'like', u'different', u'collegues', u'have', u'a', u'different', u'way', u'of', u'thinking']
# removed all non-english words : [u'like', u'different', u'have', u'a', u'different', u'way', u'of', u'thinking']
#
# sentence : overall
# tokenizer : [u'overall']
# removed all non-english words : [u'overall']
#
# sentence : all of the ibmers are in creative thinking platform
# tokenizer : [u'all', u'of', u'the', u'ibmers', u'are', u'in', u'creative', u'thinking', u'platform']
# removed all non-english words : [u'all', u'of', u'the', u'are', u'in', u'creative', u'thinking', u'platform']
#
# sentence : &gt; hardest part of my job &amp; as well as in my professional carrier is
# tokenizer : [u'gt', u'hardest', u'part', u'of', u'my', u'job', u'amp', u'as', u'well', u'as', u'in', u'my', u'professional', u'carrier', u'is']
# removed all non-english words : [u'gt', u'hardest', u'part', u'of', u'my', u'job', u'amp', u'as', u'well', u'as', u'in', u'my', u'professional', u'carrier', u'is']
#
# sentence : leaving the ibm- wish to comeback
# tokenizer : [u'leaving', u'the', u'ibm', u'wish', u'to', u'comeback']
# removed all non-english words : [u'leaving', u'the', u'wish', u'to', u'comeback']
#
# sentence : i am trying the same at present
# tokenizer : [u'i', u'am', u'trying', u'the', u'same', u'at', u'present']
# removed all non-english words : [u'i', u'am', u'trying', u'the', u'same', u'at', u'present']
#
# sentence : &gt;when i got a gem award
# tokenizer : [u'gt', u'when', u'i', u'got', u'a', u'gem', u'award']
# removed all non-english words : [u'gt', u'when', u'i', u'got', u'a', u'gem', u'award']
#
# sentence :
# tokenizer : []
# removed all non-english words : []
# Review :  more than 2,10 year of experience in ibm from bangalre , working for unilever process take care for there accounts in entire world,like invoice processing and payment and vendor maintenance,etc   it was an inbound process, mostly handling vendor and client  calls and helping them finding a better solution for their problem,it was a nice time with the co-workers, they were very supportive and helping peoples,i have learned a lot of client care experience, beginning it was quite tough to handle invoice  , but after some days i managed every thing  like p2p and r2r and o2c and started to give better solutions to the customers and make them happy so that i can also enjoy my happiness,from my career i got one message,"give and take respect"
#
# sentence :  more than 2,10 year of experience in ibm from bangalre
# tokenizer : [u'more', u'than', u'year', u'of', u'experience', u'in', u'ibm', u'from', u'bangalre']
# removed all non-english words : [u'more', u'than', u'year', u'of', u'experience', u'in', u'from']
#
# sentence : working for unilever process take care for there accounts in entire world,like invoice processing
# tokenizer : [u'working', u'for', u'unilever', u'process', u'take', u'care', u'for', u'there', u'accounts', u'in', u'entire', u'world', u'like', u'invoice', u'processing']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-88b118452b25> in <module>()
#       1 #'tokens' contain all the tokens
# ----> 2 tokens=tokenize_all(dataset)
#
# <ipython-input-5-c4f16f42eea6> in tokenize_all(dataset)
#       2     tokens=[]
#       3     for review in dataset:
# ----> 4         tokens=tokens+tokenize_review(review)
#       5     return tokens
#
# <ipython-input-50-f718281e1bfc> in tokenize_review(review)
#       7     for sentence in sentences:
#       8         print ' '
# ----> 9         temp=preprocess(sentence)
#      10         if(len(temp)>1):
#      11             review_tokens.append(temp)
#
# <ipython-input-38-c492b9bc9205> in preprocess(sentence)
#       6     #remove_stopword=[word for word in temp if word not in all_stopwords]    # removing stopwords
#       7     #print 'stopwords : '+ str(remove_stopword)
# ----> 8     only_english=[word for word in temp if dictionary.check(word)== True]  # remove non-english words
#       9     print 'removed all non-english words : '+str(only_english)
#      10     return  only_english           # returns tokens
#
# /home/pranav/anaconda2/lib/python2.7/site-packages/enchant/__init__.pyc in check(self, word)
#     646         if len(word) == 0:
#     647             raise ValueError("can't check spelling of empty string")
# --> 648         val = _e.dict_check(self._this,word.encode())
#     649         if val == 0:
#     650             return True
#
# /home/pranav/anaconda2/lib/python2.7/site-packages/enchant/_enchant.pyc in dict_check(dict, word)
#     251 dict_check1.restype = c_int
#     252 def dict_check(dict,word):
# --> 253     return dict_check1(dict,word,len(word))
#     254
#     255 dict_suggest1 = e.enchant_dict_suggest
#
# KeyboardInterrupt:

# %%
#storing entire tokens to a a file
with open('tokens.txt','w') as f:
    json.dump(tokens,f)

# %%
len(tokens)
# Out:
# 249932

# %%
# training word2vec
model = gensim.models.Word2Vec(tokens, min_count=5, workers=2)
model.save('model')              #saves the model

# %%
#testing most_similar
#model.most_similar('work')

# %%
#testing similarity
#model.similarity('job','work')

# %%
# testing load feature
#new_model=gensim.models.Word2Vec.load('model')
#new_model.most_similar('work')
