# %%
import nltk
import random
import os
import json
from nltk.stem import  PorterStemmer
from nltk.corpus import stopwords
import enchant
from nltk.tokenize import RegexpTokenizer

# %%
#initialising dictionary, tokenizer, stemmer
dictionary = enchant.Dict("en_US")
tokenizer=RegexpTokenizer('[a-zA-Z]+')
ps=PorterStemmer()
all_stopwords=stopwords.words('english')+['ism','amazon']

# %%
def preprocess_dataset():  
    dataset=[]
    for root, dirs, files in os.walk('../Dataset'):
        for directory in dirs:
            print directory
            for root_f, dirs_f, files_f in os.walk(os.path.join(root,directory)):
                for each_file in files_f:
                    with open(os.path.join(root,directory)+'/'+each_file) as f:
                        data_temp=json.load(f)
                    dataset=preprocess(data_temp)  
                    with open(os.path.join(root,directory)+'/'+each_file,'w') as f:
                        json.dump(dataset,f)
                    print each_file+' completed'

# %%
def preprocess(data):
    dataset=[]
    for sentence in data:
        #print 'sentence'
        #print sentence
        temp=tokenizer.tokenize(sentence)
        #print 'tokenizer'
        #print temp
        remove_stopword=[word for word in temp if word not in all_stopwords]    # removing stopwords
        #print 'stopwords'
        #print remove_stopword
        only_english=[ps.stem(word) for word in remove_stopword if dictionary.check(word)== True]  # remove non-english words
        #print 'removed all non-english words'
        #print only_english
        if(len(only_english)>1):                  #appends only if length of list >1
            dataset.append(' '.join(only_english))
    return dataset

# %%
dataset=load_dataset()

# %%
dataset[1500]
# Out:
# u' enjoyed my job well'

# %%
sample=preprocess(dataset[196000:200000])
#print sample
# Out:
# [u'good workplac', u'good work environ', u'great work cultur', u'find good cultur peopl amp safe environ', u'provid great environ grow', u'environ also realli great', u'cultur adventur great', u'adventur realli good workplac stabil', u'excel work environ', u'work cultur good', u'employe make good environ', u'good workplac cultur', u'provid great environ grow', u'environ also realli great', u'great work environ', u'good compani good cultur', u'nice work cultur friendli environ manag', u'great cultur encourag peopl contribut product deliveri', u'excel work cultur', u'great cultur core valu', u'provid great environ grow', u'environ also realli great', u'best compani fresh healthi work environ good leader ship great manag cultur ethic work life balanc optic', u'amaz experi work', u'great work cultur', u'good behavior work experi nice', u'emphasi provid excel environ work', u'adventur best work place cultur', u'project time get work skill set good learn environ manag good workplac cultur good', u'work environ good', u'provid great environ grow', u'environ also realli great', u'work adventur excel experi', u'nice compani work peopl look nice environ product job safeti', u'work cultur great', u'adventur one best work cultur', u'environ product good facil', u'provid great environ grow', u'environ also realli great', u'adventur good work environ', u'work cultur nice', u'best cultur around', u'team bend unforgett experi', u'great work environ learn mani new thing good peopl around transport facil work cultur fun work great manag peer pressur', u'like work cultur adventur', u'provid great environ grow', u'environ also realli great', u'work cultur adventur great', u'great learn well defin procedur best peopl one global network hygien workplac technolog best conduct great visibl compani hierarchi', u'nice work cultur across portfolio', u'adventur great place work good cultur', u'provid good learn experi', u'provid great environ grow', u'environ also realli great', u'good cultur', u'great time togeth great cultur come work fun', u'good cultur', u'work environ good', u'cultur also good', u'provid great environ grow', u'environ also realli great', u'work cultur good', u'workplac cultur nice', u'great amic atmospher', u'good manag good job cultur', u'cultur good', u'great learn experi shift applic', u'provid great environ grow', u'environ also realli great', u'environ realli good', u'good work cultur fun work good employe opportun great offic meet direct interact client divers maintain', u'find good cultur peopl amp safe environ', u'good workplac adventur', u'provid great environ grow', u'environ also realli great', u'quit amaz experi adventur', u'good learn experi', u'awesom experi work adventur', u'nice place work healthi work atmospher', u'adventur brilliant work cultur incorpor amaz work life balanc manag well structur', u'great place work gave good invalu experi within maximum exposur', u'kind environ leav plan good', u'provid great environ grow', u'environ also realli great', u'amaz experi part adventur', u'good environ work', u'work adventur quit good experi', u'good experi work compani', u'nice environ', u'awesom manag lot manag help job cultur environ colleg fresh', u'provid great environ grow', u'environ also realli great', u'work cultur good adventur', u'work cultur good', u'work cultur best', u'provid great environ grow', u'environ also realli great', u'good environ', u'good learn experi', u'work shift nice environ', u'workplac cultur love work adventur target good sometim strenuou', u'good work cultur', u'cultur superb', u'provid great environ grow', u'environ also realli great', u'excel work environ', u'cultur good', u'work environ realli good', u'love work cultur', u'amaz work environ', u'experi compani great extent depend contribut merrier', u'provid great environ grow', u'environ also realli great', u'great learn experi span year adventur', u'good work cultur good environ peopl', u'good compani good work cultur good manag good ...

# %%
ps.stem('friendly')
# Out:
# u'friendli'

# %%
d = enchant.Dict("en_US")

# %%
d.check("amazon")
# Out:
# True

# %%
len(sample)
# Out:
# 400

# %%
tokenizer=RegexpTokenizer('[a-zA-Z]+')

# %%
tokenizer.tokenize('Eighty-seven miles to go, yet.  Onward!')
# Out:
# ['Eighty', 'seven', 'miles', 'to', 'go', 'yet', 'Onward']

# %%
all_stopwords=stopwords.words('english')+['ism']
'ok' in all_stopwords
# Out:
# False
